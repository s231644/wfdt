# %% [markdown]
# # Subword-level UD

# %%
from IPython.display import HTML
from collections import namedtuple
from typing import List, Optional
from dataclasses import dataclass
from copy import deepcopy

from dep_tregex.ya_dep import visualize_tree

# %% [markdown]
# ## Defining classes for storing tokens and trees

# %%
@dataclass
class CONLLUToken:
    idx: str
    form: str
    lemma: str = "_"
    upos: str = "_"
    xpos: str = "_"
    feats: str = "_"
    head: str = "0"
    deprel: str = "root"
    deps: str = "_"
    misc: str = "_"

    def __str__(self):
        return "\t".join([
            self.idx, self.form, self.lemma, self.upos, self.xpos,
            self.feats, self.head, self.deprel, self.deps, self.misc
        ])

    def __repr__(self):
        return self.__str__()

    @classmethod
    def from_str(cls, line: str):
        return cls(*line.split("\t"))

# %%
class CONLLUTree:
    def __init__(
            self,
            tokens: List[CONLLUToken],
            sent_id: str = "",
            sent_text: Optional[str] = None,
            root_idx: Optional[int] = None
    ):
        self.tokens = tokens

        if root_idx is not None:
            self.root_idx = int(root_idx)
        else:
            for i, token in enumerate(tokens):
                if token.head == "0":
                    self.root_idx = i

        self.sent_id = sent_id
        self.sent_text = sent_text or ' '.join([token.form for token in tokens])

    def __str__(self):
        return "\n".join(
            [
                f'# sent_id = {self.sent_id}',
                f'# text = {self.sent_text}'
            ] + [str(token) for token in self.tokens]
        )

    def __repr__(self):
        return self.__str__()

    def html(self, fpath: Optional[str] = None):
        content = visualize_tree("\n".join([str(token) for token in self.tokens]))
        if fpath:
            with open(fpath, "w") as f:
                f.write(content)
        return content

    @classmethod
    def from_text(cls, text: str):
        lines = text.strip().split("\n")
        tokens = [
            CONLLUToken.from_str(line)
            for line in lines if not line.startswith("#")
        ]
        return cls(tokens)

    def __len__(self):
        return len(self.tokens)

    def __iter__(self):
        iter(self.tokens)

    def __getitem__(self, item):
        return self.tokens[item]

# %%
def merge_trees(
        tree_l: CONLLUTree, tree_r: CONLLUTree,
        deprel: str, is_arc_l2r: bool = True
):
    tokens_l = deepcopy(tree_l.tokens)
    tokens_r = deepcopy(tree_r.tokens)
    l = len(tree_l.tokens)
    for t in tokens_r:
        t.idx = str(int(t.idx) + l)
        if int(t.head) > 0:
            t.head = str(int(t.head) + l)
    if is_arc_l2r:
        tokens_r[tree_r.root_idx].head = tokens_l[tree_l.root_idx].idx
        tokens_r[tree_r.root_idx].deprel = deprel
        root_idx = tree_l.root_idx
    else:
        tokens_l[tree_l.root_idx].head = str(
            int(tree_r.tokens[tree_r.root_idx].idx) + l
        )
        tokens_l[tree_l.root_idx].deprel = deprel
        root_idx = tree_r.root_idx + l
    return CONLLUTree(tokens_l + tokens_r, root_idx=root_idx)

# %% [markdown]
# ## Defining classes for storing information about word formation

# %%
WFToken = namedtuple(
    "WFToken", 
    ["derived_from_lemma", "derived_from_upos", "rule_id"]
)
WFCompoundToken = namedtuple(
    "WFCompoundToken", 
    ["derived_from_lemma", "derived_from_upos", "derived_from_modifiers", "rule_id"]
)

RuleInfo = namedtuple(
    "RuleInfo", 
    ["short_id", "info", "pos_b", "pos_a"]
)
ComplexRuleInfo = namedtuple(
    "ComplexRuleInfo", 
    ["short_id", "info", "pos_b", "pos_a", "simple_rules"]
)
CompoundRuleInfo = namedtuple(
    "CompoundRuleInfo", 
    ["short_id", "info", "pos_b", "pos_a", "head_rules", "modifier_rules", "after_rules"]
)

# %%
# TODO: create this dict automatically
rules_by_ids = {
    "при-": RuleInfo("при-", "PFX", "VERB", "VERB"),
    "на-": RuleInfo("на-", "PFX", "VERB", "VERB"),
    "об-": RuleInfo("об-", "PFX", "VERB", "VERB"),
    "-0N": RuleInfo("-0N", "SFX", "VERB", "NOUN"),
    "-н(ый)": RuleInfo("-н(ый)", "SFX", "NOUN", "ADJ"),
    "-ов(ый)": RuleInfo("-ов(ый)", "SFX", "NOUN", "ADJ"),
    "rule977(adj + о -> adv)": RuleInfo("-о", "SFX", "ADJ", "ADV"),
    "-ость": RuleInfo("-ость", "SFX", "ADJ", "NOUN"),
    "N": RuleInfo("N", "CONV", "ADJ", "NOUN"),
    "rule994(по + adj + ому -> adv)": ComplexRuleInfo(
        "по--ому", "PFX,SFX", "ADJ", "ADV", [
            RuleInfo("-ому", "SFX", "ADJ", "ADV"),
            RuleInfo("по-", "PFX", "ADV", "ADV"),
        ]
    ),
    "A+A": CompoundRuleInfo(
        "A+A", "COMPOUND", "ADJ", "ADJ", [], [], []
    ),
    "N+A": CompoundRuleInfo(
        "N+A", "COMPOUND", "ADJ", "ADJ", [], [], []
    ),
    "U+N+н(ый)": CompoundRuleInfo(
        "U+N+н(ый)", "COMPOUND,SFX", "NOUN", "ADJ", [RuleInfo("-н(ый)", "SFX", "NOUN", "ADJ")], [], []
    ),
    "A+N+н(ый)": CompoundRuleInfo(
        "A+N+н(ый)", "COMPOUND,SFX", "NOUN", "ADJ", [RuleInfo("-н(ый)", "SFX", "NOUN", "ADJ")], [], []
    )
}


derivbase = {
    "принять": WFToken("*ять", "VERB", "при-"),
    "прием": WFToken("принять", "VERB", "-0N"),
    "свободный": WFToken("свобода", "NOUN", "-н(ый)"),
    "приемный": WFToken("прием", "NOUN", "-н(ый)"),
    "приемная": WFToken("приемный", "ADJ", "N"),
    "обставить": WFToken("ставить", "VERB", "об-"),
    "просто": WFToken("простой", "ADJ", "rule977(adj + о -> adv)"),
    "дело": WFToken("делать", "VERB", "-0N"),
    "деловой": WFToken("дело", "NOUN", "-ов(ый)"),
    "по-деловому": WFToken("деловой", "ADJ", "rule994(по + adj + ому -> adv)"),
    "достоверность": WFToken("достоверный", "ADJ", "-ость"),
    "благородно": WFToken("благородный", "ADJ", "rule977(adj + о -> adv)"),
    "самозабвенно": WFToken("самозабвенный", "ADJ", "rule977(adj + о -> adv)"),
    "еда": WFToken("есть", "VERB", "-0N"),
    "сон": WFToken("спать", "VERB", "-0N"),
    "наука": WFToken("научить", "VERB", "-0N"),
    "научить": WFToken("учить", "VERB", "на-"),

    
    "достоверный": WFCompoundToken("верный", "ADJ", ("достойный",), "A+A"),
    "самозабвенный": WFCompoundToken("забвенный", "ADJ", ("себя",), "N+A"),
    "многочисленный": WFCompoundToken("число", "NOUN", ("много",), "U+N+н(ый)"),
    "белоколонный": WFCompoundToken("колона", "NOUN", ("белый",), "A+N+н(ый)"),
    "благородный": WFCompoundToken("род", "NOUN", ("благой",), "A+N+н(ый)"),
}

# %%
def merge_with_simple_rule(stem_tree: CONLLUTree, rule: RuleInfo) -> CONLLUTree:
    affix_tree = CONLLUTree([CONLLUToken("1", rule.short_id, rule.short_id)])
    if rule.info == "SFX":
        if rule.pos_a != rule.pos_b:
            tree = merge_trees(stem_tree, affix_tree, deprel="sfx", is_arc_l2r=False)
        else:
            # TODO: separate modifiers from other suffixes
            tree = merge_trees(stem_tree, affix_tree, deprel="msfx", is_arc_l2r=True)
    elif rule.info == "PTFX":
        tree = merge_trees(stem_tree, affix_tree, deprel="refl", is_arc_l2r=True)
    elif rule.info == "PFX":
        tree = merge_trees(affix_tree, stem_tree, deprel="mpfx", is_arc_l2r=False)
    elif rule.info == "CONV":
        tree = merge_trees(stem_tree, affix_tree, deprel="conv", is_arc_l2r=False)
    else:
        raise AssertionError('Rule info is incorrect!', rule.short_id, rule.info)
    return tree


def merge_with_complex_rule(stem_tree: CONLLUTree, rule: ComplexRuleInfo) -> CONLLUTree:
    tree = stem_tree
    for simple_rule in rule.simple_rules:
        tree = merge_with_simple_rule(tree, simple_rule)
    return tree


def make_wf_tree(word: str) -> CONLLUTree:
    if word not in derivbase:
        return CONLLUTree([CONLLUToken("1", word, word)])
    wf_token = derivbase[word]
    stem_tree = make_wf_tree(wf_token.derived_from_lemma)
    rule = rules_by_ids[wf_token.rule_id]
    if isinstance(rule, RuleInfo):
        return merge_with_simple_rule(stem_tree, rule)
    elif isinstance(rule, ComplexRuleInfo):
        return merge_with_complex_rule(stem_tree, rule)
    elif isinstance(rule, CompoundRuleInfo):
        modifiers_trees = [make_wf_tree(m) for m in wf_token.derived_from_modifiers]
        # TODO: rules for modifiers
        for hrule in rule.head_rules:
            stem_tree = merge_with_simple_rule(stem_tree, hrule)
        for modifier_tree in reversed(modifiers_trees):  # (m1 (m2 (m3 h))) sfx
            stem_tree = merge_trees(modifier_tree, stem_tree, "compound", is_arc_l2r=False)
        for hrule in rule.after_rules:  # prefix?
            stem_tree = merge_with_simple_rule(stem_tree, hrule)
        return stem_tree
    else:
        raise NotImplementedError


def make_wfdt(text: str):
    word_tree = CONLLUTree.from_text(text)
    subword_trees = []
    subword_roots = [-1]
    cur_len = 0
    united_subword_tokens = []
    for token in word_tree.tokens:
        subword_tree = make_wf_tree(token.lemma)
        subword_roots.append(cur_len + subword_tree.root_idx)
        subword_trees.append(subword_tree)
        for subword_token in subword_tree.tokens:
            subword_token.idx = str(len(united_subword_tokens) + 1)
            subword_token.head = str(int(subword_token.head) + cur_len)
            united_subword_tokens.append(subword_token)
        cur_len += len(subword_tree)

    renumerated = {"0": 0}
    for i, token in enumerate(word_tree.tokens):
        renumerated[token.idx] = i + 1

    for i, token in enumerate(word_tree.tokens):
        renum_head = renumerated[token.deps.split(":")[0]]
        # if token.idx.isdigit():
        #     renum_head = renumerated[token.head]
        # else:
        #     # 33.1	_	_	_	_	_	_	_	3:conj	_
        #     renum_head = renumerated[token.deps.split(":")[0]]
        united_subword_tokens[subword_roots[i+1]].head = str(subword_roots[renum_head]+1)
        united_subword_tokens[subword_roots[i+1]].deprel = token.deprel

    return CONLLUTree(united_subword_tokens)

# %% [markdown]
# ## Now let's have a look at some examples!

# %%
text = """
1	Приемная	приемная	NOUN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	3	nsubj:pass	3:nsubj:pass	_
2	была	быть	AUX	_	Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	3	aux:pass	3:aux:pass	_
3	обставлена	обставить	VERB	_	Aspect=Perf|Gender=Fem|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	0	root	0:root	_
4	просто	просто	ADV	_	Degree=Pos	3	advmod	3:advmod	SpaceAfter=No
5	,	,	PUNCT	_	_	7	punct	7:punct	_
6	но	но	CCONJ	_	_	7	cc	7:cc	_
7	по-деловому	по-деловому	ADV	_	Degree=Pos	4	conj	4:conj	SpaceAfter=No
8	.	.	PUNCT	_	_	3	punct	3:punct	_

""".strip()

# %%
t = CONLLUTree.from_text(text)

# %%
HTML(t.html())
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="624" height="138" class="svg0">
#       <style type="text/css">
#         .svg0 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg0 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg0 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg0 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg0 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg0 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg0 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg0 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg0 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg0 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg0 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg0 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg0 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg0 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg0 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg0 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg0 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg0 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg0 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg0 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg0 .w3:hover ~ .w4 > text.big { fill: #c00; }
#         .svg0 .w3 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg0 .w3:hover ~ .w4 > text.small { fill: #800; }
#         .svg0 .w3 ~ .w4_clicked > text.small { fill: #800; }
#         .svg0 .w3:hover ~ .a4 > text.role { fill: #c00; }
#         .svg0 .w3 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg0 .w3:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg0 .w3 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg0 .w3:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg0 .w3 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg0 .w7:hover ~ .w5 > text.big { fill: #c00; }
#         .svg0 .w7 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg0 .w7:hover ~ .w5 > text.small { fill: #800; }
#         .svg0 .w7 ~ .w5_clicked > text.small { fill: #800; }
#         .svg0 .w7:hover ~ .a5 > text.role { fill: #c00; }
#         .svg0 .w7 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg0 .w7:hover ~ .a5 > path.arc { stroke: #c00; }
#         .svg0 .w7 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg0 .w7:hover ~ .a5 > path.arrow { fill: #c00; }
#         .svg0 .w7 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg0 .w4:hover ~ .w5 > text.big { fill: #888; }
#         .svg0 .w4 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg0 .w4:hover ~ .w5 > text.small { fill: #666; }
#         .svg0 .w4 ~ .w5_clicked > text.small { fill: #800; }
#         .svg0 .w4:hover ~ .a5 > text.role { fill: #888; }
#         .svg0 .w4 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg0 .w4:hover ~ .a5 > path.arc { stroke: #888; }
#         .svg0 .w4 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg0 .w4:hover ~ .a5 > path.arrow { fill: #888; }
#         .svg0 .w4 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg0 .w3:hover ~ .w5 > text.big { fill: #888; }
#         .svg0 .w3 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg0 .w3:hover ~ .w5 > text.small { fill: #666; }
#         .svg0 .w3 ~ .w5_clicked > text.small { fill: #800; }
#         .svg0 .w3:hover ~ .a5 > text.role { fill: #888; }
#         .svg0 .w3 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg0 .w3:hover ~ .a5 > path.arc { stroke: #888; }
#         .svg0 .w3 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg0 .w3:hover ~ .a5 > path.arrow { fill: #888; }
#         .svg0 .w3 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg0 .w7:hover ~ .w6 > text.big { fill: #c00; }
#         .svg0 .w7 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg0 .w7:hover ~ .w6 > text.small { fill: #800; }
#         .svg0 .w7 ~ .w6_clicked > text.small { fill: #800; }
#         .svg0 .w7:hover ~ .a6 > text.role { fill: #c00; }
#         .svg0 .w7 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg0 .w7:hover ~ .a6 > path.arc { stroke: #c00; }
#         .svg0 .w7 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg0 .w7:hover ~ .a6 > path.arrow { fill: #c00; }
#         .svg0 .w7 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg0 .w4:hover ~ .w6 > text.big { fill: #888; }
#         .svg0 .w4 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg0 .w4:hover ~ .w6 > text.small { fill: #666; }
#         .svg0 .w4 ~ .w6_clicked > text.small { fill: #800; }
#         .svg0 .w4:hover ~ .a6 > text.role { fill: #888; }
#         .svg0 .w4 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg0 .w4:hover ~ .a6 > path.arc { stroke: #888; }
#         .svg0 .w4 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg0 .w4:hover ~ .a6 > path.arrow { fill: #888; }
#         .svg0 .w4 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg0 .w3:hover ~ .w6 > text.big { fill: #888; }
#         .svg0 .w3 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg0 .w3:hover ~ .w6 > text.small { fill: #666; }
#         .svg0 .w3 ~ .w6_clicked > text.small { fill: #800; }
#         .svg0 .w3:hover ~ .a6 > text.role { fill: #888; }
#         .svg0 .w3 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg0 .w3:hover ~ .a6 > path.arc { stroke: #888; }
#         .svg0 .w3 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg0 .w3:hover ~ .a6 > path.arrow { fill: #888; }
#         .svg0 .w3 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg0 .w4:hover ~ .w7 > text.big { fill: #c00; }
#         .svg0 .w4 ~ .w7_clicked > text.big { fill: #c00; }
#         .svg0 .w4:hover ~ .w7 > text.small { fill: #800; }
#         .svg0 .w4 ~ .w7_clicked > text.small { fill: #800; }
#         .svg0 .w4:hover ~ .a7 > text.role { fill: #c00; }
#         .svg0 .w4 ~ .a7_clicked > text.role { fill: #c00; }
#         .svg0 .w4:hover ~ .a7 > path.arc { stroke: #c00; }
#         .svg0 .w4 ~ .a7_clicked > path.arc { stroke: #c00; }
#         .svg0 .w4:hover ~ .a7 > path.arrow { fill: #c00; }
#         .svg0 .w4 ~ .a7_clicked > path.arrow { fill: #c00; }
#         .svg0 .w3:hover ~ .w7 > text.big { fill: #888; }
#         .svg0 .w3 ~ .w7_clicked > text.big { fill: #c00; }
#         .svg0 .w3:hover ~ .w7 > text.small { fill: #666; }
#         .svg0 .w3 ~ .w7_clicked > text.small { fill: #800; }
#         .svg0 .w3:hover ~ .a7 > text.role { fill: #888; }
#         .svg0 .w3 ~ .a7_clicked > text.role { fill: #c00; }
#         .svg0 .w3:hover ~ .a7 > path.arc { stroke: #888; }
#         .svg0 .w3 ~ .a7_clicked > path.arc { stroke: #c00; }
#         .svg0 .w3:hover ~ .a7 > path.arrow { fill: #888; }
#         .svg0 .w3 ~ .a7_clicked > path.arrow { fill: #c00; }
#         .svg0 .

# %%
HTML(make_wf_tree("многочисленный").html("многочисленный.html"))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="240" height="114" class="svg1">
#       <style type="text/css">
#         .svg1 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg1 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg1 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg1 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg1 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg1 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg1 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg1 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg1 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg1 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg1 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg1 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg1 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg1 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg1 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg1 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg1 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg1 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg1 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg1 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="120.0" y="104.0" class="big" text-anchor="start" id="subtext"> много число -н(ый)</text>
#       <g class="w3">
#         <rect x="156" y="60" width="72" height="12" class="hid" />
#         <text x="192" y="72" class="big">-н(ый)</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#       <title id="a3t">много число -н(ый)</title>
#         <path d="M 192 60 L 192 24" class="arc" />
#         <path d="M 192 60 L 192 24" class="arc hid" />
#         <path d="M 192.00 61.50L 193.94 54.26L 192.00 55.12L 190.06 54.26Z" class="arrow"/>
#         <text x="192" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="60" height="12" class="hid" />
#         <text x="42" y="72" class="big">много</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#       <title id="a1t">много</title>
#         <path d="M 42.00 60.00A 48.00 48.00 0 0 1 83.57 36.00L 144.43 36.00A 48.00 48.00 0 0 1 186.00 60.00" class="arc" />
#         <path d="M 42.00 60.00A 48.00 48.00 0 0 1 83.57 36.00L 144.43 36.00A 48.00 48.00 0 0 1 186.00 60.00" class="arc hid" />
#         <path d="M 41.25 61.30L 46.55 56.00L 44.44 55.78L 43.19 54.05Z" class="arrow"/>
#         <text x="114" y="34" class="role">compound</text>
#       </g>
#       <g class="w2">
#         <rect x="84" y="60" width="60" height="12" class="hid" />
#         <text x="114" y="72" class="big">число</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#       <title id="a2t">число</title>
#         <path d="M 114.00 60.00A 24.00 24.00 0 0 1 134.78 48.00L 165.22 48.00A 24.00 24.00 0 0 1 186.00 60.00" class="arc" />
#         <path d="M 114.00 60.00A 24.00 24.00 0 0 1 134.78 48.00L 165.22 48.00A 24.00 24.00 0 0 1 186.00 60.00" class="arc hid" />
#         <path d="M 113.25 61.30L 118.55 56.00L 116.44 55.78L 115.19 54.05Z" class="arrow"/>
#         <text x="150" y="46" class="role">sfx</text>
#       </g>
#     </svg>
#   </body>
# </html>

# %%
HTML(make_wf_tree("достоверный").html())
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="216" height="102" class="svg2">
#       <style type="text/css">
#         .svg2 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg2 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg2 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg2 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg2 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg2 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg2 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg2 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg2 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg2 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="108.0" y="92.0" class="big" text-anchor="start" id="subtext"> достойный верный</text>
#       <g class="w2">
#         <rect x="132" y="48" width="72" height="12" class="hid" />
#         <text x="168" y="60" class="big">верный</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#       <title id="a2t">достойный верный</title>
#         <path d="M 168 48 L 168 24" class="arc" />
#         <path d="M 168 48 L 168 24" class="arc hid" />
#         <path d="M 168.00 49.50L 169.94 42.26L 168.00 43.12L 166.06 42.26Z" class="arrow"/>
#         <text x="168" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="48" width="108" height="12" class="hid" />
#         <text x="66" y="60" class="big">достойный</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#       <title id="a1t">достойный</title>
#         <path d="M 66.00 48.00A 24.00 24.00 0 0 1 86.78 36.00L 141.22 36.00A 24.00 24.00 0 0 1 162.00 48.00" class="arc" />
#         <path d="M 66.00 48.00A 24.00 24.00 0 0 1 86.78 36.00L 141.22 36.00A 24.00 24.00 0 0 1 162.00 48.00" class="arc hid" />
#         <path d="M 65.25 49.30L 70.55 44.00L 68.44 43.78L 67.19 42.05Z" class="arrow"/>
#         <text x="114" y="34" class="role">compound</text>
#       </g>
#     </svg>
#   </body>
# </html>

# %%
HTML(make_wf_tree("по-деловому").html())
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="348" height="114" class="svg3">
#       <style type="text/css">
#         .svg3 .w5:hover ~ .w1 > text.big { fill: #c00; }
#         .svg3 .w5 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg3 .w5:hover ~ .w1 > text.small { fill: #800; }
#         .svg3 .w5 ~ .w1_clicked > text.small { fill: #800; }
#         .svg3 .w5:hover ~ .a1 > text.role { fill: #c00; }
#         .svg3 .w5 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg3 .w5:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg3 .w5 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg3 .w5:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg3 .w5 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg3 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg3 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg3 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg3 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg3 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg3 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg3 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg3 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg3 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg3 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg3 .w4:hover ~ .w2 > text.big { fill: #888; }
#         .svg3 .w4 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg3 .w4:hover ~ .w2 > text.small { fill: #666; }
#         .svg3 .w4 ~ .w2_clicked > text.small { fill: #800; }
#         .svg3 .w4:hover ~ .a2 > text.role { fill: #888; }
#         .svg3 .w4 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg3 .w4:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg3 .w4 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg3 .w4:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg3 .w4 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg3 .w5:hover ~ .w2 > text.big { fill: #888; }
#         .svg3 .w5 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg3 .w5:hover ~ .w2 > text.small { fill: #666; }
#         .svg3 .w5 ~ .w2_clicked > text.small { fill: #800; }
#         .svg3 .w5:hover ~ .a2 > text.role { fill: #888; }
#         .svg3 .w5 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg3 .w5:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg3 .w5 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg3 .w5:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg3 .w5 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg3 .w4:hover ~ .w3 > text.big { fill: #c00; }
#         .svg3 .w4 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg3 .w4:hover ~ .w3 > text.small { fill: #800; }
#         .svg3 .w4 ~ .w3_clicked > text.small { fill: #800; }
#         .svg3 .w4:hover ~ .a3 > text.role { fill: #c00; }
#         .svg3 .w4 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg3 .w4:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg3 .w4 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg3 .w4:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg3 .w4 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg3 .w5:hover ~ .w3 > text.big { fill: #888; }
#         .svg3 .w5 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg3 .w5:hover ~ .w3 > text.small { fill: #666; }
#         .svg3 .w5 ~ .w3_clicked > text.small { fill: #800; }
#         .svg3 .w5:hover ~ .a3 > text.role { fill: #888; }
#         .svg3 .w5 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg3 .w5:hover ~ .a3 > path.arc { stroke: #888; }
#         .svg3 .w5 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg3 .w5:hover ~ .a3 > path.arrow { fill: #888; }
#         .svg3 .w5 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg3 .w5:hover ~ .w4 > text.big { fill: #c00; }
#         .svg3 .w5 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg3 .w5:hover ~ .w4 > text.small { fill: #800; }
#         .svg3 .w5 ~ .w4_clicked > text.small { fill: #800; }
#         .svg3 .w5:hover ~ .a4 > text.role { fill: #c00; }
#         .svg3 .w5 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg3 .w5:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg3 .w5 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg3 .w5:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg3 .w5 ~ .a4_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="174.0" y="104.0" class="big" text-anchor="start" id="subtext"> по- делать -0N -ов(ый) -ому</text>
#       <g class="w5">
#         <rect x="288" y="60" width="48" height="12" class="hid" />
#         <text x="312" y="72" class="big">-ому</text>
#       </g>
#       <g id="a5" class="a5" onclick="reset('a5t', 'a5')">
#       <title id="a5t">по- делать -0N -ов(ый) -ому</title>
#         <path d="M 312 60 L 312 24" class="arc" />
#         <path d="M 312 60 L 312 24" class="arc hid" />
#         <path d="M 312.00 61.50L 313.94 54.26L 312.00 55.12L 310.06 54.26Z" class="arrow"/>
#         <text x="312" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="36" height="12" class="hid" />
#         <text x="30" y="72" class="big">по-</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#       <title id="a1t">по-</title>
#         <path d="M 30.00 60.00A 48.00 48.00 0 0 1 71.57 36.00L 264.43 36.00A 48.00 48.00 0 0 1 306.00 60.00" class="arc" />
#         <path d="M 30.00 60.00A 48.00 48.00 0 0 1 71.57 36.00L 264.43 36.00A 48.00 48.00 0 0 1 306.00 60.00" class="arc hid" />
#         <path d="M 29.25 61.30L 34.55 56.00L 32.44 55.78L 31.19 54.05Z" class="arrow"/>
#         <text x="168" y="34" class="role">mpfx</text>
#       </g>
#       <g class="w4">
#         <rect x="192" y="60" width="84" height="12" class="hid" />
#         <text x="234" y="

# %%
HTML(make_wf_tree("еда").html())
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="120" height="102" class="svg4">
#       <style type="text/css">
#         .svg4 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg4 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg4 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg4 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg4 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg4 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg4 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg4 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg4 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg4 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="60.0" y="92.0" class="big" text-anchor="start" id="subtext"> есть -0N</text>
#       <g class="w2">
#         <rect x="72" y="48" width="36" height="12" class="hid" />
#         <text x="90" y="60" class="big">-0N</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#       <title id="a2t">есть -0N</title>
#         <path d="M 90 48 L 90 24" class="arc" />
#         <path d="M 90 48 L 90 24" class="arc hid" />
#         <path d="M 90.00 49.50L 91.94 42.26L 90.00 43.12L 88.06 42.26Z" class="arrow"/>
#         <text x="90" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="48" width="48" height="12" class="hid" />
#         <text x="36" y="60" class="big">есть</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#       <title id="a1t">есть</title>
#         <path d="M 36.00 48.00A 24.00 24.00 0 0 1 56.78 36.00L 63.22 36.00A 24.00 24.00 0 0 1 84.00 48.00" class="arc" />
#         <path d="M 36.00 48.00A 24.00 24.00 0 0 1 56.78 36.00L 63.22 36.00A 24.00 24.00 0 0 1 84.00 48.00" class="arc hid" />
#         <path d="M 35.25 49.30L 40.55 44.00L 38.44 43.78L 37.19 42.05Z" class="arrow"/>
#         <text x="60" y="34" class="role">sfx</text>
#       </g>
#     </svg>
#   </body>
# </html>

# %%
HTML(
    merge_trees(
        make_wf_tree("белоколонный"), 
        make_wf_tree("здание"),
        deprel="amod", is_arc_l2r=False
    ).html()
)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="336" height="114" class="svg5">
#       <style type="text/css">
#         .svg5 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg5 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg5 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg5 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg5 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg5 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg5 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg5 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg5 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg5 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg5 .w4:hover ~ .w1 > text.big { fill: #888; }
#         .svg5 .w4 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg5 .w4:hover ~ .w1 > text.small { fill: #666; }
#         .svg5 .w4 ~ .w1_clicked > text.small { fill: #800; }
#         .svg5 .w4:hover ~ .a1 > text.role { fill: #888; }
#         .svg5 .w4 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg5 .w4:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg5 .w4 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg5 .w4:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg5 .w4 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg5 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg5 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg5 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg5 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg5 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg5 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg5 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg5 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg5 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg5 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg5 .w4:hover ~ .w2 > text.big { fill: #888; }
#         .svg5 .w4 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg5 .w4:hover ~ .w2 > text.small { fill: #666; }
#         .svg5 .w4 ~ .w2_clicked > text.small { fill: #800; }
#         .svg5 .w4:hover ~ .a2 > text.role { fill: #888; }
#         .svg5 .w4 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg5 .w4:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg5 .w4 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg5 .w4:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg5 .w4 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg5 .w4:hover ~ .w3 > text.big { fill: #c00; }
#         .svg5 .w4 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg5 .w4:hover ~ .w3 > text.small { fill: #800; }
#         .svg5 .w4 ~ .w3_clicked > text.small { fill: #800; }
#         .svg5 .w4:hover ~ .a3 > text.role { fill: #c00; }
#         .svg5 .w4 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg5 .w4:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg5 .w4 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg5 .w4:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg5 .w4 ~ .a3_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="168.0" y="104.0" class="big" text-anchor="start" id="subtext"> белый колона -н(ый) здание</text>
#       <g class="w4">
#         <rect x="252" y="60" width="72" height="12" class="hid" />
#         <text x="288" y="72" class="big">здание</text>
#       </g>
#       <g id="a4" class="a4" onclick="reset('a4t', 'a4')">
#       <title id="a4t">белый колона -н(ый) здание</title>
#         <path d="M 288 60 L 288 24" class="arc" />
#         <path d="M 288 60 L 288 24" class="arc hid" />
#         <path d="M 288.00 61.50L 289.94 54.26L 288.00 55.12L 286.06 54.26Z" class="arrow"/>
#         <text x="288" y="22" class="role">root</text>
#       </g>
#       <g class="w3">
#         <rect x="168" y="60" width="72" height="12" class="hid" />
#         <text x="204" y="72" class="big">-н(ый)</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#       <title id="a3t">белый колона -н(ый)</title>
#         <path d="M 204.00 60.00A 24.00 24.00 0 0 1 224.78 48.00L 261.22 48.00A 24.00 24.00 0 0 1 282.00 60.00" class="arc" />
#         <path d="M 204.00 60.00A 24.00 24.00 0 0 1 224.78 48.00L 261.22 48.00A 24.00 24.00 0 0 1 282.00 60.00" class="arc hid" />
#         <path d="M 203.25 61.30L 208.55 56.00L 206.44 55.78L 205.19 54.05Z" class="arrow"/>
#         <text x="243" y="46" class="role">amod</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="60" height="12" class="hid" />
#         <text x="42" y="72" class="big">белый</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#       <title id="a1t">белый</title>
#         <path d="M 42.00 60.00A 48.00 48.00 0 0 1 83.57 36.00L 156.43 36.00A 48.00 48.00 0 0 1 198.00 60.00" class="arc" />
#         <path d="M 42.00 60.00A 48.00 48.00 0 0 1 83.57 36.00L 156.43 36.00A 48.00 48.00 0 0 1 198.00 60.00" class="arc hid" />
#         <path d="M 41.25 61.30L 46.55 56.00L 44.44 55.78L 43.19 54.05Z" class="arrow"/>
#         <text x="120" y="34" class="role">compound</text>
#       </g>
#       <g class="w2">
#         <rect x="84" y="60" width="72" height="12" class="hid" />
#         <text x="120" y="72" class="big">колона</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#       <title id="a2t">колона</title>
#         <path d="M 120.00 60.00A 24.00 24.00 0 0 1 140.78 48.00L 177.22 48.00A 24.00 24.00 0 0 1 198.00 60.00" class="arc" />
#         <path d="M 120.00 60.00A 24.00 24.00 0 0 1 140.78 48.00L 177.22 48.00A 24.00 24.00 0 0 1 198.00 60.00" class="arc hid" />
#         <path d="M 119.25 61.30L 124.55 56.00L 122.44 55.78L 121.19 54.05Z" class="arrow"/>
#         <text x="159"

# %%
HTML(
    merge_trees(
        make_wf_tree("обставить"), 
        make_wf_tree("по-деловому"),
        deprel="advmod", is_arc_l2r=True
    ).html()
)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="492" height="126" class="svg6">
#       <style type="text/css">
#         .svg6 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg6 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg6 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg6 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg6 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg6 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg6 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg6 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg6 .w7:hover ~ .w3 > text.big { fill: #c00; }
#         .svg6 .w7 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg6 .w7:hover ~ .w3 > text.small { fill: #800; }
#         .svg6 .w7 ~ .w3_clicked > text.small { fill: #800; }
#         .svg6 .w7:hover ~ .a3 > text.role { fill: #c00; }
#         .svg6 .w7 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg6 .w7:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg6 .w7 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg6 .w7:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg6 .w7 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg6 .w2:hover ~ .w3 > text.big { fill: #888; }
#         .svg6 .w2 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg6 .w2:hover ~ .w3 > text.small { fill: #666; }
#         .svg6 .w2 ~ .w3_clicked > text.small { fill: #800; }
#         .svg6 .w2:hover ~ .a3 > text.role { fill: #888; }
#         .svg6 .w2 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a3 > path.arc { stroke: #888; }
#         .svg6 .w2 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a3 > path.arrow { fill: #888; }
#         .svg6 .w2 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg6 .w5:hover ~ .w4 > text.big { fill: #c00; }
#         .svg6 .w5 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg6 .w5:hover ~ .w4 > text.small { fill: #800; }
#         .svg6 .w5 ~ .w4_clicked > text.small { fill: #800; }
#         .svg6 .w5:hover ~ .a4 > text.role { fill: #c00; }
#         .svg6 .w5 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg6 .w5:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg6 .w5 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg6 .w5:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg6 .w5 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg6 .w6:hover ~ .w4 > text.big { fill: #888; }
#         .svg6 .w6 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg6 .w6:hover ~ .w4 > text.small { fill: #666; }
#         .svg6 .w6 ~ .w4_clicked > text.small { fill: #800; }
#         .svg6 .w6:hover ~ .a4 > text.role { fill: #888; }
#         .svg6 .w6 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg6 .w6:hover ~ .a4 > path.arc { stroke: #888; }
#         .svg6 .w6 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg6 .w6:hover ~ .a4 > path.arrow { fill: #888; }
#         .svg6 .w6 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg6 .w7:hover ~ .w4 > text.big { fill: #888; }
#         .svg6 .w7 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg6 .w7:hover ~ .w4 > text.small { fill: #666; }
#         .svg6 .w7 ~ .w4_clicked > text.small { fill: #800; }
#         .svg6 .w7:hover ~ .a4 > text.role { fill: #888; }
#         .svg6 .w7 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg6 .w7:hover ~ .a4 > path.arc { stroke: #888; }
#         .svg6 .w7 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg6 .w7:hover ~ .a4 > path.arrow { fill: #888; }
#         .svg6 .w7 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg6 .w2:hover ~ .w4 > text.big { fill: #888; }
#         .svg6 .w2 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg6 .w2:hover ~ .w4 > text.small { fill: #666; }
#         .svg6 .w2 ~ .w4_clicked > text.small { fill: #800; }
#         .svg6 .w2:hover ~ .a4 > text.role { fill: #888; }
#         .svg6 .w2 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a4 > path.arc { stroke: #888; }
#         .svg6 .w2 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a4 > path.arrow { fill: #888; }
#         .svg6 .w2 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg6 .w6:hover ~ .w5 > text.big { fill: #c00; }
#         .svg6 .w6 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg6 .w6:hover ~ .w5 > text.small { fill: #800; }
#         .svg6 .w6 ~ .w5_clicked > text.small { fill: #800; }
#         .svg6 .w6:hover ~ .a5 > text.role { fill: #c00; }
#         .svg6 .w6 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg6 .w6:hover ~ .a5 > path.arc { stroke: #c00; }
#         .svg6 .w6 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg6 .w6:hover ~ .a5 > path.arrow { fill: #c00; }
#         .svg6 .w6 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg6 .w7:hover ~ .w5 > text.big { fill: #888; }
#         .svg6 .w7 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg6 .w7:hover ~ .w5 > text.small { fill: #666; }
#         .svg6 .w7 ~ .w5_clicked > text.small { fill: #800; }
#         .svg6 .w7:hover ~ .a5 > text.role { fill: #888; }
#         .svg6 .w7 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg6 .w7:hover ~ .a5 > path.arc { stroke: #888; }
#         .svg6 .w7 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg6 .w7:hover ~ .a5 > path.arrow { fill: #888; }
#         .svg6 .w7 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg6 .w2:hover ~ .w5 > text.big { fill: #888; }
#         .svg6 .w2 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg6 .w2:hover ~ .w5 > text.small { fill: #666; }
#         .svg6 .w2 ~ .w5_clicked > text.small { fill: #800; }
#         .svg6 .w2:hover ~ .a5 > text.role { fill: #888; }
#         .svg6 .w2 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a5 > path.arc { stroke: #888; }
#         .svg6 .w2 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a5 > path.arrow { fill: #888; }
#         .svg6 .w2 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg6 .w7:hover ~ .w6 > text.big { fill: #c00; }
#         .svg6 .w7 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg6 .w7:hover ~ .w6 > text.small { fill: #800; }
#         .svg6 .w7 ~ .w6_clicked > text.small { fill: #800; }
#         .svg6 .w7:hover ~ .a6 > text.role { fill: #c00; }
#         .svg6 .w7 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg6 .w7:hover ~ .a6 > path.arc { stroke: #c00; }
#         .svg6 .w7 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg6 .w7:hover ~ .a6 > path.arrow { fill: #c00; }
#         .svg6 .w7 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg6 .

# %%
HTML(make_wfdt(text).html("priem.html"))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="1044" height="162" class="svg7">
#       <style type="text/css">
#         .svg7 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg7 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg7 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg7 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg7 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg7 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg7 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg7 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg7 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg7 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg7 .w3:hover ~ .w1 > text.big { fill: #888; }
#         .svg7 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg7 .w3:hover ~ .w1 > text.small { fill: #666; }
#         .svg7 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg7 .w3:hover ~ .a1 > text.role { fill: #888; }
#         .svg7 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg7 .w3:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg7 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg7 .w3:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg7 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg7 .w4:hover ~ .w1 > text.big { fill: #888; }
#         .svg7 .w4 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg7 .w4:hover ~ .w1 > text.small { fill: #666; }
#         .svg7 .w4 ~ .w1_clicked > text.small { fill: #800; }
#         .svg7 .w4:hover ~ .a1 > text.role { fill: #888; }
#         .svg7 .w4 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg7 .w4:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg7 .w4 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg7 .w4:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg7 .w4 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg7 .w5:hover ~ .w1 > text.big { fill: #888; }
#         .svg7 .w5 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg7 .w5:hover ~ .w1 > text.small { fill: #666; }
#         .svg7 .w5 ~ .w1_clicked > text.small { fill: #800; }
#         .svg7 .w5:hover ~ .a1 > text.role { fill: #888; }
#         .svg7 .w5 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg7 .w5:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg7 .w5 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg7 .w5:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg7 .w5 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg7 .w8:hover ~ .w1 > text.big { fill: #888; }
#         .svg7 .w8 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg7 .w8:hover ~ .w1 > text.small { fill: #666; }
#         .svg7 .w8 ~ .w1_clicked > text.small { fill: #800; }
#         .svg7 .w8:hover ~ .a1 > text.role { fill: #888; }
#         .svg7 .w8 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg7 .w8:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg7 .w8 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg7 .w8:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg7 .w8 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg7 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg7 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg7 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg7 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg7 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg7 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg7 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg7 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg7 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg7 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg7 .w4:hover ~ .w2 > text.big { fill: #888; }
#         .svg7 .w4 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg7 .w4:hover ~ .w2 > text.small { fill: #666; }
#         .svg7 .w4 ~ .w2_clicked > text.small { fill: #800; }
#         .svg7 .w4:hover ~ .a2 > text.role { fill: #888; }
#         .svg7 .w4 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg7 .w4:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg7 .w4 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg7 .w4:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg7 .w4 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg7 .w5:hover ~ .w2 > text.big { fill: #888; }
#         .svg7 .w5 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg7 .w5:hover ~ .w2 > text.small { fill: #666; }
#         .svg7 .w5 ~ .w2_clicked > text.small { fill: #800; }
#         .svg7 .w5:hover ~ .a2 > text.role { fill: #888; }
#         .svg7 .w5 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg7 .w5:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg7 .w5 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg7 .w5:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg7 .w5 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg7 .w8:hover ~ .w2 > text.big { fill: #888; }
#         .svg7 .w8 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg7 .w8:hover ~ .w2 > text.small { fill: #666; }
#         .svg7 .w8 ~ .w2_clicked > text.small { fill: #800; }
#         .svg7 .w8:hover ~ .a2 > text.role { fill: #888; }
#         .svg7 .w8 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg7 .w8:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg7 .w8 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg7 .w8:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg7 .w8 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg7 .w4:hover ~ .w3 > text.big { fill: #c00; }
#         .svg7 .w4 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg7 .w4:hover ~ .w3 > text.small { fill: #800; }
#         .svg7 .w4 ~ .w3_clicked > text.small { fill: #800; }
#         .svg7 .w4:hover ~ .a3 > text.role { fill: #c00; }
#         .svg7 .w4 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg7 .w4:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg7 .w4 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg7 .w4:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg7 .w4 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg7 .w5:hover ~ .w3 > text.big { fill: #888; }
#         .svg7 .w5 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg7 .w5:hover ~ .w3 > text.small { fill: #666; }
#         .svg7 .w5 ~ .w3_clicked > text.small { fill: #800; }
#         .svg7 .w5:hover ~ .a3 > text.role { fill: #888; }
#         .svg7 .w5 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg7 .w5:hover ~ .a3 > path.arc { stroke: #888; }
#         .svg7 .w5 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg7 .w5:hover ~ .a3 > path.arrow { fill: #888; }
#         .svg7 .w5 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg7

# %%
HTML(make_wfdt("""
# sent_id = uppsalaBitov_1.xml_196
# text = Но почти ничего с материальной достоверностью зрения.
1	Но	но	CCONJ	_	_	3	cc	3:cc	_
2	почти	почти	ADV	_	Degree=Pos	3	obl	3:obl	_
3	ничего	ничто	PRON	_	Case=Gen	0	root	0:root	_
4	с	с	ADP	_	_	6	case	6:case	_
5	материальной	материальный	ADJ	_	Case=Ins|Degree=Pos|Gender=Fem|Number=Sing	6	amod	6:amod	_
6	достоверностью	достоверность	NOUN	_	Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing	3	nmod	3:nmod	_
7	зрения	зрение	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	6	nmod	6:nmod	SpaceAfter=No
8	.	.	PUNCT	_	_	3	punct	3:punct	_
""").html())
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="756" height="150" class="svg8">
#       <style type="text/css">
#         .svg8 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg8 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg8 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg8 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg8 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg8 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg8 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg8 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg8 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg8 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg8 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg8 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg8 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg8 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg8 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg8 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg8 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg8 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg8 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg8 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg8 .w8:hover ~ .w4 > text.big { fill: #c00; }
#         .svg8 .w8 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg8 .w8:hover ~ .w4 > text.small { fill: #800; }
#         .svg8 .w8 ~ .w4_clicked > text.small { fill: #800; }
#         .svg8 .w8:hover ~ .a4 > text.role { fill: #c00; }
#         .svg8 .w8 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg8 .w8:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg8 .w8 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg8 .w8:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg8 .w8 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg8 .w3:hover ~ .w4 > text.big { fill: #888; }
#         .svg8 .w3 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg8 .w3:hover ~ .w4 > text.small { fill: #666; }
#         .svg8 .w3 ~ .w4_clicked > text.small { fill: #800; }
#         .svg8 .w3:hover ~ .a4 > text.role { fill: #888; }
#         .svg8 .w3 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg8 .w3:hover ~ .a4 > path.arc { stroke: #888; }
#         .svg8 .w3 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg8 .w3:hover ~ .a4 > path.arrow { fill: #888; }
#         .svg8 .w3 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg8 .w8:hover ~ .w5 > text.big { fill: #c00; }
#         .svg8 .w8 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg8 .w8:hover ~ .w5 > text.small { fill: #800; }
#         .svg8 .w8 ~ .w5_clicked > text.small { fill: #800; }
#         .svg8 .w8:hover ~ .a5 > text.role { fill: #c00; }
#         .svg8 .w8 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg8 .w8:hover ~ .a5 > path.arc { stroke: #c00; }
#         .svg8 .w8 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg8 .w8:hover ~ .a5 > path.arrow { fill: #c00; }
#         .svg8 .w8 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg8 .w3:hover ~ .w5 > text.big { fill: #888; }
#         .svg8 .w3 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg8 .w3:hover ~ .w5 > text.small { fill: #666; }
#         .svg8 .w3 ~ .w5_clicked > text.small { fill: #800; }
#         .svg8 .w3:hover ~ .a5 > text.role { fill: #888; }
#         .svg8 .w3 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg8 .w3:hover ~ .a5 > path.arc { stroke: #888; }
#         .svg8 .w3 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg8 .w3:hover ~ .a5 > path.arrow { fill: #888; }
#         .svg8 .w3 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg8 .w7:hover ~ .w6 > text.big { fill: #c00; }
#         .svg8 .w7 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg8 .w7:hover ~ .w6 > text.small { fill: #800; }
#         .svg8 .w7 ~ .w6_clicked > text.small { fill: #800; }
#         .svg8 .w7:hover ~ .a6 > text.role { fill: #c00; }
#         .svg8 .w7 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg8 .w7:hover ~ .a6 > path.arc { stroke: #c00; }
#         .svg8 .w7 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg8 .w7:hover ~ .a6 > path.arrow { fill: #c00; }
#         .svg8 .w7 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg8 .w8:hover ~ .w6 > text.big { fill: #888; }
#         .svg8 .w8 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg8 .w8:hover ~ .w6 > text.small { fill: #666; }
#         .svg8 .w8 ~ .w6_clicked > text.small { fill: #800; }
#         .svg8 .w8:hover ~ .a6 > text.role { fill: #888; }
#         .svg8 .w8 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg8 .w8:hover ~ .a6 > path.arc { stroke: #888; }
#         .svg8 .w8 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg8 .w8:hover ~ .a6 > path.arrow { fill: #888; }
#         .svg8 .w8 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg8 .w3:hover ~ .w6 > text.big { fill: #888; }
#         .svg8 .w3 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg8 .w3:hover ~ .w6 > text.small { fill: #666; }
#         .svg8 .w3 ~ .w6_clicked > text.small { fill: #800; }
#         .svg8 .w3:hover ~ .a6 > text.role { fill: #888; }
#         .svg8 .w3 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg8 .w3:hover ~ .a6 > path.arc { stroke: #888; }
#         .svg8 .w3 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg8 .w3:hover ~ .a6 > path.arrow { fill: #888; }
#         .svg8 .w3 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg8 .w8:hover ~ .w7 > text.big { fill: #c00; }
#         .svg8 .w8 ~ .w7_clicked > text.big { fill: #c00; }
#         .svg8 .w8:hover ~ .w7 > text.small { fill: #800; }
#         .svg8 .w8 ~ .w7_clicked > text.small { fill: #800; }
#         .svg8 .w8:hover ~ .a7 > text.role { fill: #c00; }
#         .svg8 .w8 ~ .a7_clicked > text.role { fill: #c00; }
#         .svg8 .w8:hover ~ .a7 > path.arc { stroke: #c00; }
#         .svg8 .w8 ~ .a7_clicked > path.arc { stroke: #c00; }
#         .svg8 .w8:hover ~ .a7 > path.arrow { fill: #c00; }
#         .svg8 .w8 ~ .a7_clicked > path.arrow { fill: #c00; }
#         .svg8 .w3:hover ~ .w7 > text.big { fill: #888; }
#         .svg8 .w3 ~ .w7_clicked > text.big { fill: #c00; }
#         .svg8 .w3:hover ~ .w7 > text.small { fill: #666; }
#         .svg8 .w3 ~ .w7_clicked > text.small { fill: #800; }
#         .svg8 .w3:hover ~ .a7 > text.role { fill: #888; }
#         .svg8 .w3 ~ .a7_clicked > text.role { fill: #c00; }
#         .svg8 .w3:hover ~ .a7 > path.arc { stroke: #888; }
#         .svg8 .w3 ~ .a7_clicked > path.arc { stroke: #c00; }
#         .svg8 .w3:hover ~ .a7 > path.arrow { fill: #888; }
#         .svg8 .w3 ~ .a7_clicked > path.arrow { fill: #c00; }
#         .svg8 .

# %%
HTML(make_wfdt("""
# text = В них находил он необыкновенно приятный тон благопристойности и почтения и тогда воображал себя не иначе как уже стариком, окруженным многочисленными учениками, членом многочисленных ученых обществ, а собственную жизнь - каким-то непрерывным чествованием.
1	В	в	ADP	_	_	2	case	2:case	_
2	них	они	PRON	_	Case=Loc|Number=Plur|Person=3	3	obl	3:obl	_
3	находил	находить	VERB	_	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	0	root	0:root	_
4	он	он	PRON	_	Case=Nom|Gender=Masc|Number=Sing|Person=3	3	nsubj	3:nsubj	_
5	необыкновенно	необыкновенно	ADV	_	Degree=Pos	6	obl	6:obl	_
6	приятный	приятный	ADJ	_	Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing	7	amod	7:amod	_
7	тон	тон	NOUN	_	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	3	obj	3:obj	_
8	благопристойности	благопристойность	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	7	nmod	7:nmod	_
9	и	и	CCONJ	_	_	10	cc	10:cc	_
10	почтения	почтение	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	8	conj	8:conj	_
11	и	и	CCONJ	_	_	13	cc	13:cc	_
12	тогда	тогда	ADV	_	Degree=Pos	13	advmod	13:advmod	_
13	воображал	воображать	VERB	_	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	3	conj	3:conj	_
14	себя	себя	PRON	_	Case=Acc	13	obj	13:obj	_
15	не	не	PART	_	_	16	advmod	16:advmod	_
16	иначе	иначе	ADV	_	Degree=Pos	13	advmod	13:advmod	_
17	как	как	SCONJ	_	_	19	mark	19:mark	_
18	уже	уже	ADV	_	Degree=Pos	19	obl	19:obl	_
19	стариком	старик	NOUN	_	Animacy=Anim|Case=Ins|Gender=Masc|Number=Sing	16	obl	16:obl	SpaceAfter=No
20	,	,	PUNCT	_	_	21	punct	21:punct	_
21	окруженным	окружить	VERB	_	Aspect=Perf|Case=Ins|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	19	acl	19:acl	_
22	многочисленными	многочисленный	ADJ	_	Case=Ins|Degree=Pos|Number=Plur	23	amod	23:amod	_
23	учениками	ученик	NOUN	_	Animacy=Anim|Case=Ins|Gender=Masc|Number=Plur	21	obl	21:obl	SpaceAfter=No
24	,	,	PUNCT	_	_	25	punct	25:punct	_
25	членом	член	NOUN	_	Animacy=Anim|Case=Ins|Gender=Masc|Number=Sing	19	conj	19:conj	_
26	многочисленных	многочисленный	ADJ	_	Case=Gen|Degree=Pos|Number=Plur	28	amod	28:amod	_
27	ученых	ученый	ADJ	_	Case=Gen|Degree=Pos|Number=Plur	28	amod	28:amod	_
28	обществ	общество	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur	25	nmod	25:nmod	SpaceAfter=No
29	,	,	PUNCT	_	_	32	punct	32:punct	_
30	а	а	CCONJ	_	_	32	cc	33.1:cc	_
31	собственную	собственный	ADJ	_	Case=Acc|Degree=Pos|Gender=Fem|Number=Sing	32	amod	32:amod	_
32	жизнь	жизнь	NOUN	_	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	3	conj	33.1:obj	_
33	-	-	PUNCT	_	_	36	punct	36:punct	_
33.1	_	_	_	_	_	_	_	3:conj	_
34	каким-то	какой-то	DET	_	Case=Ins|Gender=Neut|Number=Sing	36	det	36:det	_
35	непрерывным	непрерывный	ADJ	_	Case=Ins|Degree=Pos|Gender=Neut|Number=Sing	36	amod	36:amod	_
36	чествованием	чествование	NOUN	_	Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing	32	orphan	33.1:obl	SpaceAfter=No
37	.	.	PUNCT	_	_	3	punct	3:punct	_
""").html("uppsalaBitov_2.xml_38.html"))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="3185" height="162" class="svg9">
#       <style type="text/css">
#         .svg9 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg9 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg9 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg9 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg9 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg9 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg9 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg9 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg9 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg9 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg9 .w3:hover ~ .w1 > text.big { fill: #888; }
#         .svg9 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg9 .w3:hover ~ .w1 > text.small { fill: #666; }
#         .svg9 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg9 .w3:hover ~ .a1 > text.role { fill: #888; }
#         .svg9 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg9 .w3:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg9 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg9 .w3:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg9 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg9 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg9 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg9 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg9 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg9 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg9 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg9 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg9 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg9 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg9 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg9 .w3:hover ~ .w4 > text.big { fill: #c00; }
#         .svg9 .w3 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg9 .w3:hover ~ .w4 > text.small { fill: #800; }
#         .svg9 .w3 ~ .w4_clicked > text.small { fill: #800; }
#         .svg9 .w3:hover ~ .a4 > text.role { fill: #c00; }
#         .svg9 .w3 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg9 .w3:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg9 .w3 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg9 .w3:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg9 .w3 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg9 .w6:hover ~ .w5 > text.big { fill: #c00; }
#         .svg9 .w6 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg9 .w6:hover ~ .w5 > text.small { fill: #800; }
#         .svg9 .w6 ~ .w5_clicked > text.small { fill: #800; }
#         .svg9 .w6:hover ~ .a5 > text.role { fill: #c00; }
#         .svg9 .w6 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg9 .w6:hover ~ .a5 > path.arc { stroke: #c00; }
#         .svg9 .w6 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg9 .w6:hover ~ .a5 > path.arrow { fill: #c00; }
#         .svg9 .w6 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg9 .w7:hover ~ .w5 > text.big { fill: #888; }
#         .svg9 .w7 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg9 .w7:hover ~ .w5 > text.small { fill: #666; }
#         .svg9 .w7 ~ .w5_clicked > text.small { fill: #800; }
#         .svg9 .w7:hover ~ .a5 > text.role { fill: #888; }
#         .svg9 .w7 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg9 .w7:hover ~ .a5 > path.arc { stroke: #888; }
#         .svg9 .w7 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg9 .w7:hover ~ .a5 > path.arrow { fill: #888; }
#         .svg9 .w7 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg9 .w3:hover ~ .w5 > text.big { fill: #888; }
#         .svg9 .w3 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg9 .w3:hover ~ .w5 > text.small { fill: #666; }
#         .svg9 .w3 ~ .w5_clicked > text.small { fill: #800; }
#         .svg9 .w3:hover ~ .a5 > text.role { fill: #888; }
#         .svg9 .w3 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg9 .w3:hover ~ .a5 > path.arc { stroke: #888; }
#         .svg9 .w3 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg9 .w3:hover ~ .a5 > path.arrow { fill: #888; }
#         .svg9 .w3 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg9 .w7:hover ~ .w6 > text.big { fill: #c00; }
#         .svg9 .w7 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg9 .w7:hover ~ .w6 > text.small { fill: #800; }
#         .svg9 .w7 ~ .w6_clicked > text.small { fill: #800; }
#         .svg9 .w7:hover ~ .a6 > text.role { fill: #c00; }
#         .svg9 .w7 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg9 .w7:hover ~ .a6 > path.arc { stroke: #c00; }
#         .svg9 .w7 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg9 .w7:hover ~ .a6 > path.arrow { fill: #c00; }
#         .svg9 .w7 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg9 .w3:hover ~ .w6 > text.big { fill: #888; }
#         .svg9 .w3 ~ .w6_clicked > text.big { fill: #c00; }
#         .svg9 .w3:hover ~ .w6 > text.small { fill: #666; }
#         .svg9 .w3 ~ .w6_clicked > text.small { fill: #800; }
#         .svg9 .w3:hover ~ .a6 > text.role { fill: #888; }
#         .svg9 .w3 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg9 .w3:hover ~ .a6 > path.arc { stroke: #888; }
#         .svg9 .w3 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg9 .w3:hover ~ .a6 > path.arrow { fill: #888; }
#         .svg9 .w3 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg9 .w3:hover ~ .w7 > text.big { fill: #c00; }
#         .svg9 .w3 ~ .w7_clicked > text.big { fill: #c00; }
#         .svg9 .w3:hover ~ .w7 > text.small { fill: #800; }
#         .svg9 .w3 ~ .w7_clicked > text.small { fill: #800; }
#         .svg9 .w3:hover ~ .a7 > text.role { fill: #c00; }
#         .svg9 .w3 ~ .a7_clicked > text.role { fill: #c00; }
#         .svg9 .w3:hover ~ .a7 > path.arc { stroke: #c00; }
#         .svg9 .w3 ~ .a7_clicked > path.arc { stroke: #c00; }
#         .svg9 .w3:hover ~ .a7 > path.arrow { fill: #c00; }
#         .svg9 .w3 ~ .a7_clicked > path.arrow { fill: #c00; }
#         .svg9 .w7:hover ~ .w8 > text.big { fill: #c00; }
#         .svg9 .w7 ~ .w8_clicked > text.big { fill: #c00; }
#         .svg9 .w7:hover ~ .w8 > text.small { fill: #800; }
#         .svg9 .w7 ~ .w8_clicked > text.small { fill: #800; }
#         .svg9 .w7:hover ~ .a8 > text.role { fill: #c00; }
#         .svg9 .w7 ~ .a8_clicked > text.role { fill: #c00; }
#         .svg9 .w7:hover ~ .a8 > path.arc { stroke: #c00; }
#         .svg9 .w7 ~ .a8_clicked > path.arc { stroke: #c00; }
#         .svg9 .w7:hover ~ .a8 > path.arrow { fill: #c00; }
#         .svg9 .w7 ~ .a8_clicked > path.arrow { fill: #c00; }
#         .svg9

# %%
make_wfdt("""# sent_id = uppsalaBitov_2.xml_43
# text = Он представлял, как самозабвенно и благородно трудятся люди в этом большом белоколонном здании, а также в старинных, чуть ли не елизаветинских, деревянных домиках - лабораториях, разбросанных там и сям по прекрасному парку.
1	Он	он	PRON	_	Case=Nom|Gender=Masc|Number=Sing|Person=3	2	nsubj	2:nsubj	_
2	представлял	представлять	VERB	_	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	0	root	0:root	SpaceAfter=No
3	,	,	PUNCT	_	_	8	punct	8:punct	_
4	как	как	SCONJ	_	_	8	mark	8:mark	_
5	самозабвенно	самозабвенно	ADV	_	Degree=Pos	8	advmod	8:advmod	_
6	и	и	CCONJ	_	_	7	cc	7:cc	_
7	благородно	благородно	ADV	_	Degree=Pos	5	conj	5:conj	_
8	трудятся	трудиться	VERB	_	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Mid	2	ccomp	2:ccomp	_
9	люди	человек	NOUN	_	Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur	8	nsubj	8:nsubj	_
10	в	в	ADP	_	_	14	case	14:case	_
11	этом	этот	DET	_	Case=Loc|Gender=Neut|Number=Sing	14	det	14:det	_
12	большом	большой	ADJ	_	Case=Loc|Degree=Pos|Gender=Neut|Number=Sing	14	amod	14:amod	_
13	белоколонном	белоколонный	ADJ	_	Case=Loc|Degree=Pos|Gender=Neut|Number=Sing	14	amod	14:amod	_
14	здании	здание	NOUN	_	Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing	8	obl	8:obl	SpaceAfter=No
15	,	,	PUNCT	_	_	27	punct	27:punct	_
16	а	а	CCONJ	_	_	27	cc	27:cc	_
17	также	также	PART	_	_	16	fixed	16:fixed	_
18	в	в	ADP	_	_	27	case	27:case	_
19	старинных	старинный	ADJ	_	Case=Loc|Degree=Pos|Number=Plur	27	amod	27:amod	SpaceAfter=No
20	,	,	PUNCT	_	_	24	punct	24:punct	_
21	чуть	чуть	ADV	_	Degree=Pos	23	advmod	23:advmod	_
22	ли	ли	PART	_	_	21	advmod	21:advmod	_
23	не	не	PART	_	_	24	advmod	24:advmod	_
24	елизаветинских	елизаветинский	ADJ	_	Case=Loc|Degree=Pos|Number=Plur	19	conj	19:conj	SpaceAfter=No
25	,	,	PUNCT	_	_	26	punct	26:punct	_
26	деревянных	деревянный	ADJ	_	Case=Loc|Degree=Pos|Number=Plur	19	conj	19:conj	_
27	домиках	домик	NOUN	_	Animacy=Inan|Case=Loc|Gender=Masc|Number=Plur	14	conj	14:conj	_
28	-	-	PUNCT	_	_	29	punct	29:punct	_
29	лабораториях	лаборатория	NOUN	_	Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur	27	appos	27:appos	SpaceAfter=No
30	,	,	PUNCT	_	_	31	punct	31:punct	_
31	разбросанных	разбросить	VERB	_	Aspect=Perf|Case=Loc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass	27	acl	27:acl	_
32	там	там	ADV	_	Degree=Pos	31	advmod	31:advmod	_
33	и	и	CCONJ	_	_	34	cc	34:cc	_
34	сям	сям	ADV	_	Degree=Pos	32	conj	32:conj	_
35	по	по	ADP	_	_	37	case	37:case	_
36	прекрасному	прекрасный	ADJ	_	Case=Dat|Degree=Pos|Gender=Masc|Number=Sing	37	amod	37:amod	_
37	парку	парк	NOUN	_	Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing	31	obl	31:obl	SpaceAfter=No
38	.	.	PUNCT	_	_	2	punct	2:punct	_
""").html("uppsalaBitov_2.xml_43.html");

# %%
make_wfdt("""# sent_id = 2007Grechko.xml_253
# text = Для занятий наукой я выбирал "свободное" время, то есть выкраивал его за счет еды и сна.
1	Для	для	ADP	_	_	2	case	2:case	_
2	занятий	занятие	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur	5	obl	5:obl	_
3	наукой	наука	NOUN	_	Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing	2	nmod	2:nmod	_
4	я	я	PRON	_	Case=Nom|Number=Sing|Person=1	5	nsubj	5:nsubj	_
5	выбирал	выбирать	VERB	_	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	0	root	0:root	_
6	"	"	PUNCT	_	_	7	punct	7:punct	SpaceAfter=No
7	свободное	свободный	ADJ	_	Case=Acc|Degree=Pos|Gender=Neut|Number=Sing	9	amod	9:amod	SpaceAfter=No
8	"	"	PUNCT	_	_	7	punct	7:punct	_
9	время	время	NOUN	_	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	5	obj	5:obj	SpaceAfter=No
10	,	,	PUNCT	_	_	13	punct	13:punct	_
11	то	то	PRON	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	13	mark	13:mark	_
12	есть	быть	VERB	_	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	11	fixed	11:fixed	_
13	выкраивал	выкраивать	VERB	_	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act	5	parataxis	5:parataxis	_
14	его	он	PRON	_	Case=Acc|Gender=Masc|Number=Sing|Person=3	13	obj	13:obj	_
15	за	за	ADP	_	_	17	case	17:case	_
16	счет	счет	NOUN	_	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	15	fixed	15:fixed	_
17	еды	еда	NOUN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	13	obl	13:obl	_
18	и	и	CCONJ	_	_	19	cc	19:cc	_
19	сна	сон	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	17	conj	17:conj	SpaceAfter=No
20	.	.	PUNCT	_	_	5	punct	5:punct	_""").html("2007Grechko.xml_253.html");
