# %% [markdown]
# # Subword-level UD

# %%
import sys
sys.path.append("../")

from IPython.display import HTML

from src import (
    LexItem, WFToken,
    RuleInfo, ComplexRuleInfo, CompoundRuleInfo,
    Inventory, unite_inventories
)

# %% [markdown]
# ## Storing information about word formation

# %%
rules_by_ids = {
    "-able": RuleInfo("-able", "SFX", "NOUN", "ADJ"),
    "-ite": RuleInfo("-ite", "SFX", "VERB", "ADV"),
    "-ly": RuleInfo("-ly", "SFX", "ADJ", "ADV"),

    "in-": RuleInfo("in-", "PFX", "ADJ", "ADJ"),

    "ADJ + NOUN + -ed -> ADJ": CompoundRuleInfo(
        "A+N+ed", "COMPOUND,SFX", "NOUN", "ADJ",
        [RuleInfo("-ed", "SFX", "NOUN", "ADJ")], [[]], []
    ),
}

# %%
lexicon = {
    'comfort': LexItem(
        lemma='comfort', form='comfort', upos='NOUN'
    ),
    'comfortable': LexItem(
        lemma='comfortable', form='comfortable', upos='ADJ'
    ),
    'define': LexItem(
        lemma='define', form='define', upos='VERB'
    ),
    'definite': LexItem(
        lemma='definite', form='definite', upos='ADJ'
    ),
    'indefinite': LexItem(
        lemma='indefinite', form='indefinite', upos='ADJ'
    ),
    'indefinitely': LexItem(
        lemma='indefinitely', form='indefinitely', upos='ADV'
    ),
    'eye': LexItem(
        lemma='eye', form='eye', upos='NOUN'
    ),
    'green': LexItem(
        lemma='green', form='green', upos='ADJ'
    ),
    'green-eyed': LexItem(
        lemma='green-eyed', form='green-eyed', upos='ADJ'
    ),
}

# %%
word_analyses = {
    lexicon['comfortable']: WFToken(
        d_from=lexicon['comfort'],
        rule_id='-able',
    ),
    lexicon['definite']: WFToken(
        d_from=lexicon['define'],
        rule_id='-ite',
    ),
    lexicon['indefinite']: WFToken(
        d_from=lexicon['definite'],
        rule_id='in-',
    ),
    lexicon['indefinitely']: WFToken(
        d_from=lexicon['indefinite'],
        rule_id='-ly',
    ),
    lexicon['green-eyed']: WFToken(
        d_from=lexicon['eye'],
        rule_id="ADJ + NOUN + -ed -> ADJ",
        d_modifiers=[lexicon['green']]
    )
}

# %%
inventory = Inventory(
    word_analyses=word_analyses,
    rules_by_ids=rules_by_ids
)

# %% [markdown]
# ## Now let's have a look at some examples!

# %%
for word in word_analyses:
    subword_tree = inventory.make_subword_tree(word)
    subword_tree.html(fpath=f"tree_{word.lemma}_{word.upos}.html")

# %%
ud_sentence = """
# sent_id = weblog-blogspot.com_rigorousintuition_20050518101500_ENG_20050518_101500-0028
# text = So instead Posada may be held indefinitely, in comfortable custody.
1	So	so	ADV	RB	_	6	advmod	6:advmod	_
2	instead	instead	ADV	RB	_	6	advmod	6:advmod	_
3	Posada	Posada	PROPN	NNP	Number=Sing	6	nsubj:pass	6:nsubj:pass	_
4	may	may	AUX	MD	VerbForm=Fin	6	aux	6:aux	_
5	be	be	AUX	VB	VerbForm=Inf	6	aux:pass	6:aux:pass	_
6	held	hold	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	0	root	0:root	_
7	indefinitely	indefinitely	ADV	RB	_	6	advmod	6:advmod	SpaceAfter=No
8	,	,	PUNCT	,	_	6	punct	6:punct	_
9	in	in	ADP	IN	_	11	case	11:case	_
10	comfortable	comfortable	ADJ	JJ	Degree=Pos	11	amod	11:amod	_
11	custody	custody	NOUN	NN	Number=Sing	6	obl	6:obl:in	SpaceAfter=No
12	.	.	PUNCT	.	_	6	punct	6:punct	_
""".strip()

tree = inventory.make_tree(ud_sentence)
tree_html = tree.html()

# print(tree.latex())

# %%
HTML(tree_html)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="965" height="150" class="svg5">
#       <style type="text/css">
#         .svg5 .w6:hover ~ .w1 > text.big { fill: #c00; }
#         .svg5 .w6 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w1 > text.small { fill: #800; }
#         .svg5 .w6 ~ .w1_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a1 > text.role { fill: #c00; }
#         .svg5 .w6 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg5 .w6 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg5 .w6 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .w2 > text.big { fill: #c00; }
#         .svg5 .w6 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w2 > text.small { fill: #800; }
#         .svg5 .w6 ~ .w2_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a2 > text.role { fill: #c00; }
#         .svg5 .w6 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg5 .w6 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg5 .w6 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .w3 > text.big { fill: #c00; }
#         .svg5 .w6 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w3 > text.small { fill: #800; }
#         .svg5 .w6 ~ .w3_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a3 > text.role { fill: #c00; }
#         .svg5 .w6 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg5 .w6 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg5 .w6 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .w4 > text.big { fill: #c00; }
#         .svg5 .w6 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w4 > text.small { fill: #800; }
#         .svg5 .w6 ~ .w4_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a4 > text.role { fill: #c00; }
#         .svg5 .w6 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg5 .w6 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg5 .w6 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .w5 > text.big { fill: #c00; }
#         .svg5 .w6 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w5 > text.small { fill: #800; }
#         .svg5 .w6 ~ .w5_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a5 > text.role { fill: #c00; }
#         .svg5 .w6 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a5 > path.arc { stroke: #c00; }
#         .svg5 .w6 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a5 > path.arrow { fill: #c00; }
#         .svg5 .w6 ~ .a5_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .a6 > text.role { fill: #c00; }
#         .svg5 .w6 ~ .a6_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a6 > path.arc { stroke: #c00; }
#         .svg5 .w6 ~ .a6_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a6 > path.arrow { fill: #c00; }
#         .svg5 .w6 ~ .a6_clicked > path.arrow { fill: #c00; }
#         .svg5 .w8:hover ~ .w7 > text.big { fill: #c00; }
#         .svg5 .w8 ~ .w7_clicked > text.big { fill: #c00; }
#         .svg5 .w8:hover ~ .w7 > text.small { fill: #800; }
#         .svg5 .w8 ~ .w7_clicked > text.small { fill: #800; }
#         .svg5 .w8:hover ~ .a7 > text.role { fill: #c00; }
#         .svg5 .w8 ~ .a7_clicked > text.role { fill: #c00; }
#         .svg5 .w8:hover ~ .a7 > path.arc { stroke: #c00; }
#         .svg5 .w8 ~ .a7_clicked > path.arc { stroke: #c00; }
#         .svg5 .w8:hover ~ .a7 > path.arrow { fill: #c00; }
#         .svg5 .w8 ~ .a7_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .w7 > text.big { fill: #888; }
#         .svg5 .w6 ~ .w7_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w7 > text.small { fill: #666; }
#         .svg5 .w6 ~ .w7_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a7 > text.role { fill: #888; }
#         .svg5 .w6 ~ .a7_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a7 > path.arc { stroke: #888; }
#         .svg5 .w6 ~ .a7_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a7 > path.arrow { fill: #888; }
#         .svg5 .w6 ~ .a7_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .w8 > text.big { fill: #c00; }
#         .svg5 .w6 ~ .w8_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w8 > text.small { fill: #800; }
#         .svg5 .w6 ~ .w8_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a8 > text.role { fill: #c00; }
#         .svg5 .w6 ~ .a8_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a8 > path.arc { stroke: #c00; }
#         .svg5 .w6 ~ .a8_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a8 > path.arrow { fill: #c00; }
#         .svg5 .w6 ~ .a8_clicked > path.arrow { fill: #c00; }
#         .svg5 .w8:hover ~ .w9 > text.big { fill: #c00; }
#         .svg5 .w8 ~ .w9_clicked > text.big { fill: #c00; }
#         .svg5 .w8:hover ~ .w9 > text.small { fill: #800; }
#         .svg5 .w8 ~ .w9_clicked > text.small { fill: #800; }
#         .svg5 .w8:hover ~ .a9 > text.role { fill: #c00; }
#         .svg5 .w8 ~ .a9_clicked > text.role { fill: #c00; }
#         .svg5 .w8:hover ~ .a9 > path.arc { stroke: #c00; }
#         .svg5 .w8 ~ .a9_clicked > path.arc { stroke: #c00; }
#         .svg5 .w8:hover ~ .a9 > path.arrow { fill: #c00; }
#         .svg5 .w8 ~ .a9_clicked > path.arrow { fill: #c00; }
#         .svg5 .w6:hover ~ .w9 > text.big { fill: #888; }
#         .svg5 .w6 ~ .w9_clicked > text.big { fill: #c00; }
#         .svg5 .w6:hover ~ .w9 > text.small { fill: #666; }
#         .svg5 .w6 ~ .w9_clicked > text.small { fill: #800; }
#         .svg5 .w6:hover ~ .a9 > text.role { fill: #888; }
#         .svg5 .w6 ~ .a9_clicked > text.role { fill: #c00; }
#         .svg5 .w6:hover ~ .a9 > path.arc { stroke: #888; }
#         .svg5 .w6 ~ .a9_clicked > path.arc { stroke: #c00; }
#         .svg5 .w6:hover ~ .a9 > path.arrow { fill: #888; }
#         .svg5 .w6 ~ .a9_clicked > path.arrow { fill: #c00; }
#         .svg5 .w8:hover ~ .w10 > text.big { fill: #c00; }
#         .svg5 .w8 ~ .w10_clicked > text.big { fill: #c00; }
#         .svg5 .w8:hover ~ .w10 > text.small { fill: #800; }
#         .svg5 .w8 ~ .w10_clicked > text.small { fill: #800; }
#         .sv

# %%
HTML(inventory.make_subword_tree(lexicon["indefinitely"]).html("indefinitely.html"))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="252" height="114" class="svg6">
#       <style type="text/css">
#         .svg6 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg6 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg6 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg6 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg6 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg6 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg6 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg6 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg6 .w2:hover ~ .a2 > text.role { fill: #c00; }
#         .svg6 .w2 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg6 .w2 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg6 .w2 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg6 .w2:hover ~ .w3 > text.big { fill: #c00; }
#         .svg6 .w2 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg6 .w2:hover ~ .w3 > text.small { fill: #800; }
#         .svg6 .w2 ~ .w3_clicked > text.small { fill: #800; }
#         .svg6 .w2:hover ~ .a3 > text.role { fill: #c00; }
#         .svg6 .w2 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg6 .w2 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg6 .w2 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg6 .w2:hover ~ .w4 > text.big { fill: #c00; }
#         .svg6 .w2 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg6 .w2:hover ~ .w4 > text.small { fill: #800; }
#         .svg6 .w2 ~ .w4_clicked > text.small { fill: #800; }
#         .svg6 .w2:hover ~ .a4 > text.role { fill: #c00; }
#         .svg6 .w2 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg6 .w2:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg6 .w2 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg6 .w2:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg6 .w2 ~ .a4_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="126.0" y="104.0" class="big" text-anchor="start" id="subtext"> in- define -ite -ly</text>
#       <g class="w2">
#         <rect x="60" y="60" width="72" height="12" class="hid" />
#         <text x="96" y="72" class="big">define</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#         <title id="a2t">in- define -ite -ly</title>
#         <path d="M 96 60 L 96 24" class="arc" />
#         <path d="M 96 60 L 96 24" class="arc hid" />
#         <path d="M 96.00 61.50L 97.94 54.26L 96.00 55.12L 94.06 54.26Z" class="arrow"/>
#         <text x="96" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="36" height="12" class="hid" />
#         <text x="30" y="72" class="big">in-</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#         <title id="a1t">in-</title>
#         <path d="M 30.00 60.00A 24.00 24.00 0 0 1 50.78 48.00L 69.22 48.00A 24.00 24.00 0 0 1 90.00 60.00" class="arc" />
#         <path d="M 30.00 60.00A 24.00 24.00 0 0 1 50.78 48.00L 69.22 48.00A 24.00 24.00 0 0 1 90.00 60.00" class="arc hid" />
#         <path d="M 29.25 61.30L 34.55 56.00L 32.44 55.78L 31.19 54.05Z" class="arrow"/>
#         <text x="60" y="46" class="role">affix</text>
#       </g>
#       <g class="w3">
#         <rect x="144" y="60" width="48" height="12" class="hid" />
#         <text x="168" y="72" class="big">-ite</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#         <title id="a3t">-ite</title>
#         <path d="M 102.00 60.00A 24.00 24.00 0 0 1 122.78 48.00L 147.22 48.00A 24.00 24.00 0 0 1 168.00 60.00" class="arc" />
#         <path d="M 102.00 60.00A 24.00 24.00 0 0 1 122.78 48.00L 147.22 48.00A 24.00 24.00 0 0 1 168.00 60.00" class="arc hid" />
#         <path d="M 168.75 61.30L 166.81 54.05L 165.56 55.78L 163.45 56.00Z" class="arrow"/>
#         <text x="135" y="46" class="role">affix</text>
#       </g>
#       <g class="w4">
#         <rect x="204" y="60" width="36" height="12" class="hid" />
#         <text x="222" y="72" class="big">-ly</text>
#       </g>
#       <g id="a4" class="a4" onclick="reset('a4t', 'a4')">
#         <title id="a4t">-ly</title>
#         <path d="M 102.00 60.00A 48.00 48.00 0 0 1 143.57 36.00L 180.43 36.00A 48.00 48.00 0 0 1 222.00 60.00" class="arc" />
#         <path d="M 102.00 60.00A 48.00 48.00 0 0 1 143.57 36.00L 180.43 36.00A 48.00 48.00 0 0 1 222.00 60.00" class="arc hid" />
#         <path d="M 222.75 61.30L 220.81 54.05L 219.56 55.78L 217.45 56.00Z" class="arrow"/>
#         <text x="162" y="34" class="role">affix</text>
#       </g>
#     </svg>
#   </body>
# </html>

# %%
HTML(inventory.make_subword_tree(lexicon["green-eyed"]).html("green-eyed.html"))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="185" height="102" class="svg7">
#       <style type="text/css">
#         .svg7 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg7 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg7 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg7 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg7 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg7 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg7 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg7 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg7 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg7 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg7 .w2:hover ~ .a2 > text.role { fill: #c00; }
#         .svg7 .w2 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg7 .w2:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg7 .w2 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg7 .w2:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg7 .w2 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg7 .w2:hover ~ .w3 > text.big { fill: #c00; }
#         .svg7 .w2 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg7 .w2:hover ~ .w3 > text.small { fill: #800; }
#         .svg7 .w2 ~ .w3_clicked > text.small { fill: #800; }
#         .svg7 .w2:hover ~ .a3 > text.role { fill: #c00; }
#         .svg7 .w2 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg7 .w2:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg7 .w2 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg7 .w2:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg7 .w2 ~ .a3_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="92.78460969082653" y="92.0" class="big" text-anchor="start" id="subtext"> green eye -ed</text>
#       <g class="w2">
#         <rect x="84" y="48" width="36" height="12" class="hid" />
#         <text x="102" y="60" class="big">eye</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#         <title id="a2t">green eye -ed</title>
#         <path d="M 102 48 L 102 24" class="arc" />
#         <path d="M 102 48 L 102 24" class="arc hid" />
#         <path d="M 102.00 49.50L 103.94 42.26L 102.00 43.12L 100.06 42.26Z" class="arrow"/>
#         <text x="102" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="48" width="60" height="12" class="hid" />
#         <text x="42" y="60" class="big">green</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#         <title id="a1t">green</title>
#         <path d="M 42.00 48.00A 24.00 24.00 0 0 1 62.78 36.00L 75.22 36.00A 24.00 24.00 0 0 1 96.00 48.00" class="arc" />
#         <path d="M 42.00 48.00A 24.00 24.00 0 0 1 62.78 36.00L 75.22 36.00A 24.00 24.00 0 0 1 96.00 48.00" class="arc hid" />
#         <path d="M 41.25 49.30L 46.55 44.00L 44.44 43.78L 43.19 42.05Z" class="arrow"/>
#         <text x="69" y="34" class="role">compound</text>
#       </g>
#       <g class="w3">
#         <rect x="137" y="48" width="36" height="12" class="hid" />
#         <text x="155" y="60" class="big">-ed</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#         <title id="a3t">-ed</title>
#         <path d="M 108.00 48.00A 24.00 24.00 0 0 1 128.78 36.00L 134.78 36.00A 24.00 24.00 0 0 1 155.57 48.00" class="arc" />
#         <path d="M 108.00 48.00A 24.00 24.00 0 0 1 128.78 36.00L 134.78 36.00A 24.00 24.00 0 0 1 155.57 48.00" class="arc hid" />
#         <path d="M 156.32 49.30L 154.38 42.05L 153.13 43.78L 151.02 44.00Z" class="arrow"/>
#         <text x="131" y="34" class="role">affix</text>
#       </g>
#     </svg>
#   </body>
# </html>

# %% [markdown]
# ## Using data from existing resources

# %%
from data_readers import *

# %% [markdown]
# ### [afr] Afrikaans: AuCoPro

# %%
afr_inventory = AuCoProReader(lang="afr").build_inventory(
    "../data/afr/aucopro/sample.txt",
    # "../data/afr/aucopro/List.AUCOPRO.AfrikaansSplitting.txt",
    bracketing_strategy="last"  # "last", "head", "chain"
)

query = LexItem(
    lang="afr",
    lemma="woordeskatitems",
    form="woordeskatitems",
    upos="NOUN",
)

tree = afr_inventory.make_subword_tree(
    query
).html(f"{query.lang}_{query.lemma}_{query.upos}.html")

HTML(tree)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="252" height="114" class="svg14">
#       <style type="text/css">
#         .svg14 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg14 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg14 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg14 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg14 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg14 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg14 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg14 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg14 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg14 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg14 .w4:hover ~ .w1 > text.big { fill: #888; }
#         .svg14 .w4 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg14 .w4:hover ~ .w1 > text.small { fill: #666; }
#         .svg14 .w4 ~ .w1_clicked > text.small { fill: #800; }
#         .svg14 .w4:hover ~ .a1 > text.role { fill: #888; }
#         .svg14 .w4 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg14 .w4:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg14 .w4 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg14 .w4:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg14 .w4 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg14 .w1:hover ~ .w2 > text.big { fill: #c00; }
#         .svg14 .w1 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg14 .w1:hover ~ .w2 > text.small { fill: #800; }
#         .svg14 .w1 ~ .w2_clicked > text.small { fill: #800; }
#         .svg14 .w1:hover ~ .a2 > text.role { fill: #c00; }
#         .svg14 .w1 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg14 .w1:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg14 .w1 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg14 .w1:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg14 .w1 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg14 .w3:hover ~ .w2 > text.big { fill: #888; }
#         .svg14 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg14 .w3:hover ~ .w2 > text.small { fill: #666; }
#         .svg14 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg14 .w3:hover ~ .a2 > text.role { fill: #888; }
#         .svg14 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg14 .w3:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg14 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg14 .w3:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg14 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg14 .w4:hover ~ .w2 > text.big { fill: #888; }
#         .svg14 .w4 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg14 .w4:hover ~ .w2 > text.small { fill: #666; }
#         .svg14 .w4 ~ .w2_clicked > text.small { fill: #800; }
#         .svg14 .w4:hover ~ .a2 > text.role { fill: #888; }
#         .svg14 .w4 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg14 .w4:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg14 .w4 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg14 .w4:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg14 .w4 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg14 .w4:hover ~ .w3 > text.big { fill: #c00; }
#         .svg14 .w4 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg14 .w4:hover ~ .w3 > text.small { fill: #800; }
#         .svg14 .w4 ~ .w3_clicked > text.small { fill: #800; }
#         .svg14 .w4:hover ~ .a3 > text.role { fill: #c00; }
#         .svg14 .w4 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg14 .w4:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg14 .w4 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg14 .w4:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg14 .w4 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg14 .w4:hover ~ .a4 > text.role { fill: #c00; }
#         .svg14 .w4 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg14 .w4:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg14 .w4 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg14 .w4:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg14 .w4 ~ .a4_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="126.0" y="104.0" class="big" text-anchor="start" id="subtext"> woord -e skat items</text>
#       <g class="w4">
#         <rect x="180" y="60" width="60" height="12" class="hid" />
#         <text x="210" y="72" class="big">items</text>
#       </g>
#       <g id="a4" class="a4" onclick="reset('a4t', 'a4')">
#         <title id="a4t">woord -e skat items</title>
#         <path d="M 210 60 L 210 24" class="arc" />
#         <path d="M 210 60 L 210 24" class="arc hid" />
#         <path d="M 210.00 61.50L 211.94 54.26L 210.00 55.12L 208.06 54.26Z" class="arrow"/>
#         <text x="210" y="22" class="role">root</text>
#       </g>
#       <g class="w3">
#         <rect x="120" y="60" width="48" height="12" class="hid" />
#         <text x="144" y="72" class="big">skat</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#         <title id="a3t">woord -e skat</title>
#         <path d="M 144.00 60.00A 24.00 24.00 0 0 1 164.78 48.00L 183.22 48.00A 24.00 24.00 0 0 1 204.00 60.00" class="arc" />
#         <path d="M 144.00 60.00A 24.00 24.00 0 0 1 164.78 48.00L 183.22 48.00A 24.00 24.00 0 0 1 204.00 60.00" class="arc hid" />
#         <path d="M 143.25 61.30L 148.55 56.00L 146.44 55.78L 145.19 54.05Z" class="arrow"/>
#         <text x="174" y="46" class="role">compound</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="60" height="12" class="hid" />
#         <text x="42" y="72" class="big">woord</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#         <title id="a1t">woord -e</title>
#         <path d="M

# %% [markdown]
# ### [deu] German: DErivBase 2.0 from UDer 1.1 and GermaNet

# %%
deu_derivation_inventory = UDerReader(lang="deu").build_inventory(
    "../data/deu/derivbase-uder/sample.txt",
    "../data/deu/rules_sample.json"
)
deu_compounding_inventory = GermaNetReader(lang="deu").build_inventory(
    "../data/deu/germanet/sample.txt"
    # "../data/deu/germanet/split_compounds_from_GermaNet17.0.txt"
)
deu_inventory = unite_inventories(deu_derivation_inventory, deu_compounding_inventory)

query = LexItem(
    lang="deu",
    lemma="Olympiamedaillengewinner",
    form="Olympiamedaillengewinner",
    upos="NOUN",
)

tree = deu_inventory.make_subword_tree(
    query
).html(f"{query.lang}_{query.lemma}_{query.upos}.html")

HTML(tree)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="408" height="114" class="svg13">
#       <style type="text/css">
#         .svg13 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg13 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg13 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg13 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg13 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg13 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg13 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg13 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg13 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg13 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg13 .w4:hover ~ .w1 > text.big { fill: #888; }
#         .svg13 .w4 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg13 .w4:hover ~ .w1 > text.small { fill: #666; }
#         .svg13 .w4 ~ .w1_clicked > text.small { fill: #800; }
#         .svg13 .w4:hover ~ .a1 > text.role { fill: #888; }
#         .svg13 .w4 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg13 .w4:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg13 .w4 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg13 .w4:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg13 .w4 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg13 .w4:hover ~ .w2 > text.big { fill: #c00; }
#         .svg13 .w4 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg13 .w4:hover ~ .w2 > text.small { fill: #800; }
#         .svg13 .w4 ~ .w2_clicked > text.small { fill: #800; }
#         .svg13 .w4:hover ~ .a2 > text.role { fill: #c00; }
#         .svg13 .w4 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg13 .w4:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg13 .w4 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg13 .w4:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg13 .w4 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg13 .w2:hover ~ .w3 > text.big { fill: #c00; }
#         .svg13 .w2 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg13 .w2:hover ~ .w3 > text.small { fill: #800; }
#         .svg13 .w2 ~ .w3_clicked > text.small { fill: #800; }
#         .svg13 .w2:hover ~ .a3 > text.role { fill: #c00; }
#         .svg13 .w2 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg13 .w2:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg13 .w2 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg13 .w2:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg13 .w2 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg13 .w4:hover ~ .w3 > text.big { fill: #888; }
#         .svg13 .w4 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg13 .w4:hover ~ .w3 > text.small { fill: #666; }
#         .svg13 .w4 ~ .w3_clicked > text.small { fill: #800; }
#         .svg13 .w4:hover ~ .a3 > text.role { fill: #888; }
#         .svg13 .w4 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg13 .w4:hover ~ .a3 > path.arc { stroke: #888; }
#         .svg13 .w4 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg13 .w4:hover ~ .a3 > path.arrow { fill: #888; }
#         .svg13 .w4 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg13 .w4:hover ~ .a4 > text.role { fill: #c00; }
#         .svg13 .w4 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg13 .w4:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg13 .w4 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg13 .w4:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg13 .w4 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg13 .w4:hover ~ .w5 > text.big { fill: #c00; }
#         .svg13 .w4 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg13 .w4:hover ~ .w5 > text.small { fill: #800; }
#         .svg13 .w4 ~ .w5_clicked > text.small { fill: #800; }
#         .svg13 .w4:hover ~ .a5 > text.role { fill: #c00; }
#         .svg13 .w4 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg13 .w4:hover ~ .a5 > path.arc { stroke: #c00; }
#         .svg13 .w4 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg13 .w4:hover ~ .a5 > path.arrow { fill: #c00; }
#         .svg13 .w4 ~ .a5_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="204.0" y="104.0" class="big" text-anchor="start" id="subtext"> Olympia Medaille -n gewinnen -er</text>
#       <g class="w4">
#         <rect x="252" y="60" width="96" height="12" class="hid" />
#         <text x="300" y="72" class="big">gewinnen</text>
#       </g>
#       <g id="a4" class="a4" onclick="reset('a4t', 'a4')">
#         <title id="a4t">Olympia Medaille -n gewinnen -er</title>
#         <path d="M 300 60 L 300 24" class="arc" />
#         <path d="M 300 60 L 300 24" class="arc hid" />
#         <path d="M 300.00 61.50L 301.94 54.26L 300.00 55.12L 298.06 54.26Z" class="arrow"/>
#         <text x="300" y="22" class="role">root</text>
#       </g>
#       <g class="w2">
#         <rect x="108" y="60" width="96" height="12" class="hid" />
#         <text x="156" y="72" class="big">Medaille</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#         <title id="a2t">Olympia Medaille -n</title>
#         <path d="M 156.00 60.00A 48.00 48.00 0 0 1 197.57 36.00L 252.43 36.00A 48.00 48.00 0 0 1 294.00 60.00" class="arc" />
#         <path d="M 156.00 60.00A 48.00 48.00 0 0 1 197.57 36.00L 252.43 36.00A 48.00 48.00 0 0 1 294.00 60.00" class="arc hid" />
#         <path d="M 155.25 61.30L 160.55 56.00L 158.44 55.78L 157.19 54.05Z" class="arrow"/>
#         <text x="225" y="34" class="role">compound</text>
#       </g>
#       <g class="w5">
#         <rect x="360" y="60" width="36" height="12" class="hid" />
#         <text x="378" y="72" class="big">-er</text>
#       </g>
#       <g id="a5" class="a5" onclick="reset('a5t', 'a5')">
#         <title id="a

# %% [markdown]
# ### [fra] French: Demonext

# %%
fra_inventory = DemonextReader(lang="fra").build_inventory(
    "../data/fra/demonext/sample.txt"
    # "../data/fra/demonext/relations.csv"
)

query = LexItem(
    lang="fra",
    lemma="anti-inflammatoire",
    form="anti-inflammatoire",
    upos="NOUN",
    xpos="Nm"
)

tree = fra_inventory.make_subword_tree(
    query
).html(f"{query.lang}_{query.lemma}_{query.upos}.html")

HTML(tree)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="312" height="114" class="svg16">
#       <style type="text/css">
#         .svg16 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg16 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg16 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg16 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg16 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg16 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg16 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg16 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg16 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg16 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg16 .w3:hover ~ .w2 > text.big { fill: #c00; }
#         .svg16 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg16 .w3:hover ~ .w2 > text.small { fill: #800; }
#         .svg16 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg16 .w3:hover ~ .a2 > text.role { fill: #c00; }
#         .svg16 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg16 .w3:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg16 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg16 .w3:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg16 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg16 .w3:hover ~ .a3 > text.role { fill: #c00; }
#         .svg16 .w3 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg16 .w3:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg16 .w3 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg16 .w3:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg16 .w3 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg16 .w3:hover ~ .w4 > text.big { fill: #c00; }
#         .svg16 .w3 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg16 .w3:hover ~ .w4 > text.small { fill: #800; }
#         .svg16 .w3 ~ .w4_clicked > text.small { fill: #800; }
#         .svg16 .w3:hover ~ .a4 > text.role { fill: #c00; }
#         .svg16 .w3 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg16 .w3:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg16 .w3 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg16 .w3:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg16 .w3 ~ .a4_clicked > path.arrow { fill: #c00; }
#         .svg16 .w3:hover ~ .w5 > text.big { fill: #c00; }
#         .svg16 .w3 ~ .w5_clicked > text.big { fill: #c00; }
#         .svg16 .w3:hover ~ .w5 > text.small { fill: #800; }
#         .svg16 .w3 ~ .w5_clicked > text.small { fill: #800; }
#         .svg16 .w3:hover ~ .a5 > text.role { fill: #c00; }
#         .svg16 .w3 ~ .a5_clicked > text.role { fill: #c00; }
#         .svg16 .w3:hover ~ .a5 > path.arc { stroke: #c00; }
#         .svg16 .w3 ~ .a5_clicked > path.arc { stroke: #c00; }
#         .svg16 .w3:hover ~ .a5 > path.arrow { fill: #c00; }
#         .svg16 .w3 ~ .a5_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="156.0" y="104.0" class="big" text-anchor="start" id="subtext"> anti- en- flamme -oire -</text>
#       <g class="w3">
#         <rect x="132" y="60" width="72" height="12" class="hid" />
#         <text x="168" y="72" class="big">flamme</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#         <title id="a3t">anti- en- flamme -oire -</title>
#         <path d="M 168 60 L 168 24" class="arc" />
#         <path d="M 168 60 L 168 24" class="arc hid" />
#         <path d="M 168.00 61.50L 169.94 54.26L 168.00 55.12L 166.06 54.26Z" class="arrow"/>
#         <text x="168" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="60" height="12" class="hid" />
#         <text x="42" y="72" class="big">anti-</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#         <title id="a1t">anti-</title>
#         <path d="M 42.00 60.00A 48.00 48.00 0 0 1 83.57 36.00L 120.43 36.00A 48.00 48.00 0 0 1 162.00 60.00" class="arc" />
#         <path d="M 42.00 60.00A 48.00 48.00 0 0 1 83.57 36.00L 120.43 36.00A 48.00 48.00 0 0 1 162.00 60.00" class="arc hid" />
#         <path d="M 41.25 61.30L 46.55 56.00L 44.44 55.78L 43.19 54.05Z" class="arrow"/>
#         <text x="102" y="34" class="role">affix</text>
#       </g>
#       <g class="w2">
#         <rect x="84" y="60" width="36" height="12" class="hid" />
#         <text x="102" y="72" class="big">en-</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#         <title id="a2t">en-</title>
#         <path d="M 102.00 60.00A 24.00 24.00 0 0 1 122.78 48.00L 141.22 48.00A 24.00 24.00 0 0 1 162.00 60.00" class="arc" />
#         <path d="M 102.00 60.00A 24.00 24.00 0 0 1 122.78 48.00L 141.22 48.00A 24.00 24.00 0 0 1 162.00 60.00" class="arc hid" />
#         <path d="M 101.25 61.30L 106.55 56.00L 104.44 55.78L 103.19 54.05Z" class="arrow"/>
#         <text x="132" y="46" class="role">affix</text>
#       </g>
#       <g class="w4">
#         <rect x="216" y="60" width="60" height="12" class="hid" />
#         <text x="246" y="72" class="big">-oire</text>
#       </g>
#       <g id="a4" class="a4" onclick="reset('a4t', 'a4')">
#         <title id="a4t">-oire</title>
#         <path d="M 174.00 60.00A 24.00 24.00 0 0 1 194.78 48.00L 225.22 48.00A 24.00 24.00 0 0 1 246.00 60.00" class="arc" />
#         <path d="M 174.00 60.00A 24.00 24.00 0 0 1 194.78 48.00L 225.22 48.00A 24.00 24.00 0 0 1 246.00 60.00" class="arc hid" />
#         <path d="M 246.75 61.30L 244.81 54.05L 243.56 55.78L 241.45 56.00Z" class="arrow"/>
#         <text x="210" y="46" class="role">affix</text>
#       </g>
#       <g class="w5">
#         <rect x="288" y="60" width="12" height="12" class="hid" />
#         <text x="294" y="72" class="big">-</text>
#       </g>
#       <g id="a5

# %% [markdown]
# ### [nld] Dutch: AuCoPro

# %%
nld_inventory = AuCoProReader(lang="nld").build_inventory(
    "../data/nld/aucopro/sample.txt",
    # "../data/nld/aucopro/List.AUCOPRO.DutchSplitting.txt",
    bracketing_strategy="last"  # "last", "head", "chain"
)

query = LexItem(
    lang="nld",
    lemma="temperatuursverandering",
    form="temperatuursverandering",
    upos="NOUN",
)

tree = nld_inventory.make_subword_tree(
    query
).html(f"{query.lang}_{query.lemma}_{query.upos}.html")

HTML(tree)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="336" height="114" class="svg18">
#       <style type="text/css">
#         .svg18 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg18 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg18 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg18 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg18 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg18 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg18 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg18 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg18 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg18 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg18 .w1:hover ~ .w2 > text.big { fill: #c00; }
#         .svg18 .w1 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg18 .w1:hover ~ .w2 > text.small { fill: #800; }
#         .svg18 .w1 ~ .w2_clicked > text.small { fill: #800; }
#         .svg18 .w1:hover ~ .a2 > text.role { fill: #c00; }
#         .svg18 .w1 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg18 .w1:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg18 .w1 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg18 .w1:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg18 .w1 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg18 .w3:hover ~ .w2 > text.big { fill: #888; }
#         .svg18 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg18 .w3:hover ~ .w2 > text.small { fill: #666; }
#         .svg18 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg18 .w3:hover ~ .a2 > text.role { fill: #888; }
#         .svg18 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg18 .w3:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg18 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg18 .w3:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg18 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg18 .w3:hover ~ .a3 > text.role { fill: #c00; }
#         .svg18 .w3 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg18 .w3:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg18 .w3 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg18 .w3:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg18 .w3 ~ .a3_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="168.0" y="104.0" class="big" text-anchor="start" id="subtext"> temperatuur -s verandering</text>
#       <g class="w3">
#         <rect x="192" y="60" width="132" height="12" class="hid" />
#         <text x="258" y="72" class="big">verandering</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#         <title id="a3t">temperatuur -s verandering</title>
#         <path d="M 258 60 L 258 24" class="arc" />
#         <path d="M 258 60 L 258 24" class="arc hid" />
#         <path d="M 258.00 61.50L 259.94 54.26L 258.00 55.12L 256.06 54.26Z" class="arrow"/>
#         <text x="258" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="132" height="12" class="hid" />
#         <text x="78" y="72" class="big">temperatuur</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#         <title id="a1t">temperatuur -s</title>
#         <path d="M 78.00 60.00A 48.00 48.00 0 0 1 119.57 36.00L 210.43 36.00A 48.00 48.00 0 0 1 252.00 60.00" class="arc" />
#         <path d="M 78.00 60.00A 48.00 48.00 0 0 1 119.57 36.00L 210.43 36.00A 48.00 48.00 0 0 1 252.00 60.00" class="arc hid" />
#         <path d="M 77.25 61.30L 82.55 56.00L 80.44 55.78L 79.19 54.05Z" class="arrow"/>
#         <text x="165" y="34" class="role">compound</text>
#       </g>
#       <g class="w2">
#         <rect x="156" y="60" width="24" height="12" class="hid" />
#         <text x="168" y="72" class="big">-s</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#         <title id="a2t">-s</title>
#         <path d="M 84.00 60.00A 24.00 24.00 0 0 1 104.78 48.00L 147.22 48.00A 24.00 24.00 0 0 1 168.00 60.00" class="arc" />
#         <path d="M 84.00 60.00A 24.00 24.00 0 0 1 104.78 48.00L 147.22 48.00A 24.00 24.00 0 0 1 168.00 60.00" class="arc hid" />
#         <path d="M 168.75 61.30L 166.81 54.05L 165.56 55.78L 163.45 56.00Z" class="arrow"/>
#         <text x="126" y="46" class="role">infl</text>
#       </g>
#     </svg>
#   </body>
# </html>

# %% [markdown]
# ### [rus] Russian: DerivBase.Ru from UDer 1.1 and RuCompounds from UDer 1.1

# %%
rus_derivation_inventory = UDerReader(lang="rus").build_inventory(
    "../data/rus/derivbaseru-uder/sample.txt",
    "../data/rus/rules_sample.json"
)

rus_compounding_inventory = UDerReader(lang="rus").build_inventory(
    "../data/rus/rucompounds-uder/sample.txt",
    "../data/rus/rules_sample.json"
)

rus_inventory = unite_inventories(rus_derivation_inventory, rus_compounding_inventory)

query = LexItem(
    lang="rus",
    lemma="пятикомнатный",
    form="пятикомнатный",
    upos="ADJ",
)

tree = rus_inventory.make_subword_tree(
    query
).html(f"{query.lang}_{query.lemma}_{query.upos}.html")

HTML(tree)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="360" height="114" class="svg19">
#       <style type="text/css">
#         .svg19 .w3:hover ~ .w1 > text.big { fill: #c00; }
#         .svg19 .w3 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg19 .w3:hover ~ .w1 > text.small { fill: #800; }
#         .svg19 .w3 ~ .w1_clicked > text.small { fill: #800; }
#         .svg19 .w3:hover ~ .a1 > text.role { fill: #c00; }
#         .svg19 .w3 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg19 .w3:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg19 .w3 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg19 .w3:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg19 .w3 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg19 .w1:hover ~ .w2 > text.big { fill: #c00; }
#         .svg19 .w1 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg19 .w1:hover ~ .w2 > text.small { fill: #800; }
#         .svg19 .w1 ~ .w2_clicked > text.small { fill: #800; }
#         .svg19 .w1:hover ~ .a2 > text.role { fill: #c00; }
#         .svg19 .w1 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg19 .w1:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg19 .w1 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg19 .w1:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg19 .w1 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg19 .w3:hover ~ .w2 > text.big { fill: #888; }
#         .svg19 .w3 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg19 .w3:hover ~ .w2 > text.small { fill: #666; }
#         .svg19 .w3 ~ .w2_clicked > text.small { fill: #800; }
#         .svg19 .w3:hover ~ .a2 > text.role { fill: #888; }
#         .svg19 .w3 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg19 .w3:hover ~ .a2 > path.arc { stroke: #888; }
#         .svg19 .w3 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg19 .w3:hover ~ .a2 > path.arrow { fill: #888; }
#         .svg19 .w3 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg19 .w3:hover ~ .a3 > text.role { fill: #c00; }
#         .svg19 .w3 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg19 .w3:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg19 .w3 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg19 .w3:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg19 .w3 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg19 .w3:hover ~ .w4 > text.big { fill: #c00; }
#         .svg19 .w3 ~ .w4_clicked > text.big { fill: #c00; }
#         .svg19 .w3:hover ~ .w4 > text.small { fill: #800; }
#         .svg19 .w3 ~ .w4_clicked > text.small { fill: #800; }
#         .svg19 .w3:hover ~ .a4 > text.role { fill: #c00; }
#         .svg19 .w3 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg19 .w3:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg19 .w3 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg19 .w3:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg19 .w3 ~ .a4_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="180.0" y="104.0" class="big" text-anchor="start" id="subtext"> пять -о/ух/ёх/и комната -н1-</text>
#       <g class="w3">
#         <rect x="204" y="60" width="84" height="12" class="hid" />
#         <text x="246" y="72" class="big">комната</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#         <title id="a3t">пять -о/ух/ёх/и комната -н1-</title>
#         <path d="M 246 60 L 246 24" class="arc" />
#         <path d="M 246 60 L 246 24" class="arc hid" />
#         <path d="M 246.00 61.50L 247.94 54.26L 246.00 55.12L 244.06 54.26Z" class="arrow"/>
#         <text x="246" y="22" class="role">root</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="48" height="12" class="hid" />
#         <text x="36" y="72" class="big">пять</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#         <title id="a1t">пять -о/ух/ёх/и</title>
#         <path d="M 36.00 60.00A 48.00 48.00 0 0 1 77.57 36.00L 198.43 36.00A 48.00 48.00 0 0 1 240.00 60.00" class="arc" />
#         <path d="M 36.00 60.00A 48.00 48.00 0 0 1 77.57 36.00L 198.43 36.00A 48.00 48.00 0 0 1 240.00 60.00" class="arc hid" />
#         <path d="M 35.25 61.30L 40.55 56.00L 38.44 55.78L 37.19 54.05Z" class="arrow"/>
#         <text x="138" y="34" class="role">compound</text>
#       </g>
#       <g class="w4">
#         <rect x="300" y="60" width="48" height="12" class="hid" />
#         <text x="324" y="72" class="big">-н1-</text>
#       </g>
#       <g id="a4" class="a4" onclick="reset('a4t', 'a4')">
#         <title id="a4t">-н1-</title>
#         <path d="M 252.00 60.00A 24.00 24.00 0 0 1 272.78 48.00L 303.22 48.00A 24.00 24.00 0 0 1 324.00 60.00" class="arc" />
#         <path d="M 252.00 60.00A 24.00 24.00 0 0 1 272.78 48.00L 303.22 48.00A 24.00 24.00 0 0 1 324.00 60.00" class="arc hid" />
#         <path d="M 324.75 61.30L 322.81 54.05L 321.56 55.78L 319.45 56.00Z" class="arrow"/>
#         <text x="288" y="46" class="role">affix</text>
#       </g>
#       <g class="w2">
#         <rect x="72" y="60" width="120" height="12" class="hid" />
#         <text x="132" y="72" class="big">-о/ух/ёх/и</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#         <title id="a2t">-о/ух/ёх/и</title>
#         <path d="M 42.00 60.00A 24.00 24.00 0 0 1 62.78 48.00L 111.22 48.00A 24.00 24.00 0 0 1 132.00 60.00" class="arc" />
#         <path d="M 42.00 60.00A 24.00 24.00 0 0 1 62.78 48.00L 111.22 48.00A 24.00 24.00 0 0 1 132.00 60.00" class="arc hid" />
#         <path d="M 132.75 61.30L 130.81 54.05L 129.56 55.78L 127.45 56.00Z" class="arrow"/>
#         <text x="87" y="46" class="role">infl</text>
#       </g>
#     </svg>
#   </body>
# </html>

# %% [markdown]
# ### [zho] Chinese: SJTU (Shanghai Jiao Tong University) Chinese Character Dependency Treebank

# %%
zho_inventory = CharDepsReader(lang="zho").build_inventory(
    "../data/zho/chinesechardeps/sample.txt"
)

query = LexItem(
    lang="zho",
    lemma="聆听已久",
    form="聆听已久",
    upos="ADJ",
    xpos="a"
)

tree = zho_inventory.make_subword_tree(
    query
).html(f"{query.lang}_{query.lemma}_{query.upos}.html")

HTML(tree)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <style type="text/css">
#         svg { display: block; }
#     </style>
#         <style type="text/css">
#       /* Generic */
#       * { stroke: none; fill: none; transition: 0.1s ease-out, stroke-dasharray 0.02s; }
#       text { font-family: sans-serif; text-anchor: middle; cursor: default; }
#       .hid { opacity: 0.0; }
#       rect.hid { fill: #000; stroke: #000; stroke-width: 10.00px; }
#       path.hid { fill: none; stroke: #000; stroke-width: 10.00px; }
#
#       /* Labels & arcs */
#       .big { font-size: 12px; fill: #000; font-weight: bold; }
#       .small { font-size: 10px; fill: #444; }
#       .user-hl > .big   { fill: #08c; }
#       .user-hl > .small { fill: #048; }
#       .role { font-size: 10px; fill: #444; font-style: italic; }
#       .arc { stroke: black; stroke-width: 0.50px; }
#       .arrow { fill: #000; }
#
#       /* Label and arc highlight on hover */
#       g:hover > text.big { fill: #f00; }
#       g:hover > text.small { fill: #900; }
#       g:hover > text.role { fill: #f00; }
#       g:hover > path.arc { stroke: #f00; }
#       g:hover > path.arrow { fill: #f00; }
#
#       /* Arc highlight on label hover */
#       g:hover + g > text.role { fill: #f00; }
#       g:hover + g > path.arc { stroke: #f00; stroke-dasharray: 5,5; }
#       g:hover + g > path.arrow { fill: #f00; }
#     </style>
#   </head>
#   <body>
#     <svg width="184" height="114" class="svg20">
#       <style type="text/css">
#         .svg20 .w2:hover ~ .w1 > text.big { fill: #c00; }
#         .svg20 .w2 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg20 .w2:hover ~ .w1 > text.small { fill: #800; }
#         .svg20 .w2 ~ .w1_clicked > text.small { fill: #800; }
#         .svg20 .w2:hover ~ .a1 > text.role { fill: #c00; }
#         .svg20 .w2 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg20 .w2:hover ~ .a1 > path.arc { stroke: #c00; }
#         .svg20 .w2 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg20 .w2:hover ~ .a1 > path.arrow { fill: #c00; }
#         .svg20 .w2 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg20 .w4:hover ~ .w1 > text.big { fill: #888; }
#         .svg20 .w4 ~ .w1_clicked > text.big { fill: #c00; }
#         .svg20 .w4:hover ~ .w1 > text.small { fill: #666; }
#         .svg20 .w4 ~ .w1_clicked > text.small { fill: #800; }
#         .svg20 .w4:hover ~ .a1 > text.role { fill: #888; }
#         .svg20 .w4 ~ .a1_clicked > text.role { fill: #c00; }
#         .svg20 .w4:hover ~ .a1 > path.arc { stroke: #888; }
#         .svg20 .w4 ~ .a1_clicked > path.arc { stroke: #c00; }
#         .svg20 .w4:hover ~ .a1 > path.arrow { fill: #888; }
#         .svg20 .w4 ~ .a1_clicked > path.arrow { fill: #c00; }
#         .svg20 .w4:hover ~ .w2 > text.big { fill: #c00; }
#         .svg20 .w4 ~ .w2_clicked > text.big { fill: #c00; }
#         .svg20 .w4:hover ~ .w2 > text.small { fill: #800; }
#         .svg20 .w4 ~ .w2_clicked > text.small { fill: #800; }
#         .svg20 .w4:hover ~ .a2 > text.role { fill: #c00; }
#         .svg20 .w4 ~ .a2_clicked > text.role { fill: #c00; }
#         .svg20 .w4:hover ~ .a2 > path.arc { stroke: #c00; }
#         .svg20 .w4 ~ .a2_clicked > path.arc { stroke: #c00; }
#         .svg20 .w4:hover ~ .a2 > path.arrow { fill: #c00; }
#         .svg20 .w4 ~ .a2_clicked > path.arrow { fill: #c00; }
#         .svg20 .w4:hover ~ .w3 > text.big { fill: #c00; }
#         .svg20 .w4 ~ .w3_clicked > text.big { fill: #c00; }
#         .svg20 .w4:hover ~ .w3 > text.small { fill: #800; }
#         .svg20 .w4 ~ .w3_clicked > text.small { fill: #800; }
#         .svg20 .w4:hover ~ .a3 > text.role { fill: #c00; }
#         .svg20 .w4 ~ .a3_clicked > text.role { fill: #c00; }
#         .svg20 .w4:hover ~ .a3 > path.arc { stroke: #c00; }
#         .svg20 .w4 ~ .a3_clicked > path.arc { stroke: #c00; }
#         .svg20 .w4:hover ~ .a3 > path.arrow { fill: #c00; }
#         .svg20 .w4 ~ .a3_clicked > path.arrow { fill: #c00; }
#         .svg20 .w4:hover ~ .a4 > text.role { fill: #c00; }
#         .svg20 .w4 ~ .a4_clicked > text.role { fill: #c00; }
#         .svg20 .w4:hover ~ .a4 > path.arc { stroke: #c00; }
#         .svg20 .w4 ~ .a4_clicked > path.arc { stroke: #c00; }
#         .svg20 .w4:hover ~ .a4 > path.arrow { fill: #c00; }
#         .svg20 .w4 ~ .a4_clicked > path.arrow { fill: #c00; }
#       </style>
#
#     <script>
#         let last_used_view = ''
#
#         function reset(title, svg_object_class) {
#             let new_class_name = svg_object_class + '_clicked'
#             let last_used_class_name = last_used_view + '_clicked'
#
#             if (document.getElementById(svg_object_class).classList.contains(new_class_name)) {
#                 document.getElementById(svg_object_class).classList.remove(new_class_name);
#             } else {
#                 document.getElementById(svg_object_class).classList.add(new_class_name)
#             }
#
#             try {
#               if (last_used_view !== svg_object_class) {
#                 document.getElementById(last_used_view).classList.remove(last_used_class_name)
#               }
#             }
#             catch (e) {
#               console.log(e)
#             }
#
#             last_used_view = svg_object_class
#             document.getElementById("subtext").innerHTML = document.getElementById(title).innerHTML;
#         }
#     </script>
# <text x="92.35382907247958" y="104.0" class="big" text-anchor="start" id="subtext"> 聆 听 已 久</text>
#       <g class="w4">
#         <rect x="160" y="60" width="12" height="12" class="hid" />
#         <text x="166" y="72" class="big">久</text>
#       </g>
#       <g id="a4" class="a4" onclick="reset('a4t', 'a4')">
#         <title id="a4t">聆 听 已 久</title>
#         <path d="M 166 60 L 166 24" class="arc" />
#         <path d="M 166 60 L 166 24" class="arc hid" />
#         <path d="M 166.71 61.50L 168.65 54.26L 166.71 55.12L 164.77 54.26Z" class="arrow"/>
#         <text x="166" y="22" class="role">root-a</text>
#       </g>
#       <g class="w2">
#         <rect x="65" y="60" width="12" height="12" class="hid" />
#         <text x="71" y="72" class="big">听</text>
#       </g>
#       <g id="a2" class="a2" onclick="reset('a2t', 'a2')">
#         <title id="a2t">聆 听</title>
#         <path d="M 71.57 60.00A 48.00 48.00 0 0 1 113.14 36.00L 119.14 36.00A 48.00 48.00 0 0 1 160.71 60.00" class="arc" />
#         <path d="M 71.57 60.00A 48.00 48.00 0 0 1 113.14 36.00L 119.14 36.00A 48.00 48.00 0 0 1 160.71 60.00" class="arc hid" />
#         <path d="M 70.82 61.30L 76.12 56.00L 74.01 55.78L 72.76 54.05Z" class="arrow"/>
#         <text x="116" y="34" class="role">a-v-a</text>
#       </g>
#       <g class="w3">
#         <rect x="89" y="60" width="12" height="12" class="hid" />
#         <text x="95" y="72" class="big">已</text>
#       </g>
#       <g id="a3" class="a3" onclick="reset('a3t', 'a3')">
#         <title id="a3t">已</title>
#         <path d="M 95.57 60.00A 24.00 24.00 0 0 1 116.35 48.00L 139.92 48.00A 24.00 24.00 0 0 1 160.71 60.00" class="arc" />
#         <path d="M 95.57 60.00A 24.00 24.00 0 0 1 116.35 48.00L 139.92 48.00A 24.00 24.00 0 0 1 160.71 60.00" class="arc hid" />
#         <path d="M 94.82 61.30L 100.12 56.00L 98.01 55.78L 96.76 54.05Z" class="arrow"/>
#         <text x="128" y="46" class="role">a-d-a</text>
#       </g>
#       <g class="w1">
#         <rect x="12" y="60" width="12" height="12" class="hid" />
#         <text x="18" y="72" class="big">聆</text>
#       </g>
#       <g id="a1" class="a1" onclick="reset('a1t', 'a1')">
#         <title id="a1t">聆</title>
#         <path d="M 18.00 60.00A 24.00 24.00 0 0 1 38.78 48.00L 44.78 48.00A 24.00 24.00 0 0 1 65.57 60.00" class="arc" />
#         <path d="M 18.00 60.00A 24.00 24.00 0 0 1 38.78 48.00L 44.78 48.00A 24.00 24.00 0 0 1 65.57 60.00" class="arc hid" />
#         <path d="M 17.25 61.30L 22.55 56.00L 20.44 55.78L 19.19 54.05Z" class="arrow"/>
#         <text x="41" y="46" class="role">vv</text>
#       </g>
#     </svg>
#   </body>
# </html>
